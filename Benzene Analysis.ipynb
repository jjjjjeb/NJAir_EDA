# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
from citipy import citipy

# %%
benzenepath = "Database/Benzene/Benzene.csv"
benzene = pd.read_csv(benzenepath)
benzene.head()
# benzene.columns
# Out:
# /Users/SilverSurfer/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (15,24,25,39) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#   STATE_ABBR  AMA_SITE_CODE  AQS_POC PROGRAM  YEAR  QUARTER SAMPLE_DATE  \
# 0         NJ      340390004        1   SLAMS  2016        3   16-Sep-16
# 1         NJ      340390004        1   SLAMS  2016        3   18-Sep-16
# 2         NJ      340390004        1   SLAMS  2016        3   17-Sep-16
# 3         NJ      340390004        1   SLAMS  2016        3   17-Sep-16
# 4         NJ      340390004        1   SLAMS  2016        3   17-Sep-16
#
#   SAMPLE_START_TIME  AQS_PARAMETER_CODE AQS_PARAMETER_NAME  ...  \
# 0             17:00               45201            Benzene  ...
# 1             15:00               45201            Benzene  ...
# 2             07:00               45201            Benzene  ...
# ...

# %%
benzene.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 123758 entries, 0 to 123757
# Data columns (total 44 columns):
# STATE_ABBR                      123758 non-null object
# AMA_SITE_CODE                   123758 non-null int64
# AQS_POC                         123758 non-null int64
# PROGRAM                         123758 non-null object
# YEAR                            123758 non-null int64
# QUARTER                         123758 non-null int64
# SAMPLE_DATE                     123758 non-null object
# SAMPLE_START_TIME               123758 non-null object
# AQS_PARAMETER_CODE              123758 non-null int64
# AQS_PARAMETER_NAME              123758 non-null object
# DATA_SOURCE                     123758 non-null object
# DURATION_DESC                   123758 non-null object
# SAMPLE_VALUE_REPORTED           123479 non-null float64
# AQS_UNIT_CODE                   123758 non-null int64
# UNIT_DESC                       123758 non-null object
# ...

# %%
benzene.describe()
# Out:
#        AMA_SITE_CODE        AQS_POC           YEAR        QUARTER  \
# count   1.237580e+05  123758.000000  123758.000000  123758.000000
# mean    3.401814e+08       1.165638    2006.227541       2.756274
# std     8.348999e+04       0.897764       6.853115       0.606490
# min     3.400300e+08       1.000000    1990.000000       1.000000
# 25%     3.400700e+08       1.000000    2000.000000       2.000000
# 50%     3.402100e+08       1.000000    2005.000000       3.000000
# 75%     3.402300e+08       1.000000    2013.000000       3.000000
# max     3.403955e+08       9.000000    2016.000000       4.000000
#
#        AQS_PARAMETER_CODE  SAMPLE_VALUE_REPORTED  AQS_UNIT_CODE  COMMENT  \
# count            123758.0          123479.000000  123758.000000      0.0
# mean              45201.0               0.877744      60.583429      NaN
# std                   0.0               1.219851      30.262690      NaN
# min               45201.0               0.000000       8.000000      NaN
# ...

# %%
columns=['PROGRAM', 'YEAR', 'QUARTER',
       'SAMPLE_DATE', 'SAMPLE_START_TIME', 'DURATION_DESC',
       'SAMPLE_VALUE_REPORTED', 'AQS_UNIT_CODE', 'UNIT_DESC',
       'SAMPLING_FREQUENCY_CODE', 'SAMPLE_VALUE_STD_FINAL_UG_M3',
       'SAMPLE_VALUE_STD_FINAL_TYPE', 'MDL_STD_UG_M3',
       'MDL_TYPE', 'CENSUS_TRACT_POPULATION_2010', 'MONITOR_LATITUDE', 'MONITOR_LONGITUDE']
benzene_clean = benzene.filter(items=columns)

# %%
benzene_clean.head()
# Out:
#   PROGRAM  YEAR  QUARTER SAMPLE_DATE SAMPLE_START_TIME DURATION_DESC  \
# 0   SLAMS  2016        3   16-Sep-16             17:00        1 HOUR
# 1   SLAMS  2016        3   18-Sep-16             15:00        1 HOUR
# 2   SLAMS  2016        3   17-Sep-16             07:00        1 HOUR
# 3   SLAMS  2016        3   17-Sep-16             06:00        1 HOUR
# 4   SLAMS  2016        3   17-Sep-16             05:00        1 HOUR
#
#    SAMPLE_VALUE_REPORTED  AQS_UNIT_CODE          UNIT_DESC  \
# 0                  0.139              8  PARTS PER BILLION
# 1                  0.384              8  PARTS PER BILLION
# 2                  0.904              8  PARTS PER BILLION
# 3                  0.814              8  PARTS PER BILLION
# 4                  0.484              8  PARTS PER BILLION
#
#   SAMPLING_FREQUENCY_CODE  SAMPLE_VALUE_STD_FINAL_UG_M3  \
# 0                       1                      0.456957
# 1                       1                      1.214223
# ...

# %%
benzene_clean['PROGRAM'].value_counts()
# Out:
# PAMS                            92899
# SLAMS                           27342
# UATMP                            3116
# OTHER                             255
# SPECIAL PURPOSE                    95
# SCHOOL AIR TOXICS MONITORING       51
# Name: PROGRAM, dtype: int64

# %%
benzene_clean['DURATION_DESC'].value_counts()
# Out:
# 1 HOUR      119396
# 24 HOURS      4186
# 3 HOURS        176
# Name: DURATION_DESC, dtype: int64

# %%
benzene_clean['MONITOR_LATITUDE'].value_counts()
# Out:
# 40.462182    38360
# 40.283092    31304
# 39.923042    23878
# 39.934446     6356
# 40.720989     6313
# 40.641440     6133
# 40.670250     6117
# 40.853579     2973
# 40.787628      962
# 40.472825      911
# 40.726668      125
# 40.918381       92
# 40.601725       61
# 40.915747       50
# 40.927458       45
# 39.837090       27
# 40.598028       27
# 40.652053       24
# Name: MONITOR_LATITUDE, dtype: int64

# %%
benzene_clean['CENSUS_TRACT_POPULATION_2010'].value_counts()
# Out:
# 5231    38360
# 7932    31304
# 6058    23878
# 2328     6356
# 3453     6313
# 3685     6133
# 6544     6117
# 1483     2973
# 1649      962
# 1841      911
# 5143      125
# 2349       92
# 6329       61
# 3850       50
# 2505       45
# 6097       27
# 5323       27
# 6072       24
# Name: CENSUS_TRACT_POPULATION_2010, dtype: int64

# %%
benzene_hourly = benzene_clean[benzene_clean['DURATION_DESC'] == '1 HOUR']
benzene_hourly.head()
# Out:
#   PROGRAM  YEAR  QUARTER SAMPLE_DATE SAMPLE_START_TIME DURATION_DESC  \
# 0   SLAMS  2016        3   16-Sep-16             17:00        1 HOUR
# 1   SLAMS  2016        3   18-Sep-16             15:00        1 HOUR
# 2   SLAMS  2016        3   17-Sep-16             07:00        1 HOUR
# 3   SLAMS  2016        3   17-Sep-16             06:00        1 HOUR
# 4   SLAMS  2016        3   17-Sep-16             05:00        1 HOUR
#
#    SAMPLE_VALUE_REPORTED  AQS_UNIT_CODE          UNIT_DESC  \
# 0                  0.139              8  PARTS PER BILLION
# 1                  0.384              8  PARTS PER BILLION
# 2                  0.904              8  PARTS PER BILLION
# 3                  0.814              8  PARTS PER BILLION
# 4                  0.484              8  PARTS PER BILLION
#
#   SAMPLING_FREQUENCY_CODE  SAMPLE_VALUE_STD_FINAL_UG_M3  \
# 0                       1                      0.456957
# 1                       1                      1.214223
# ...

# %%
benzene_hourly['PROGRAM'].value_counts()
# Out:
# PAMS     92743
# SLAMS    26653
# Name: PROGRAM, dtype: int64

# %%
benzene_daily = benzene_clean[benzene_clean['DURATION_DESC'] == '24 HOURS']
benzene_daily.head()
# Out:
#      PROGRAM  YEAR  QUARTER SAMPLE_DATE SAMPLE_START_TIME DURATION_DESC  \
# 1808   UATMP  2009        1   25-Jan-09             00:00      24 HOURS
# 1809   UATMP  2009        3   22-Sep-09             00:00      24 HOURS
# 1810   UATMP  2009        2   07-Apr-09             00:00      24 HOURS
# 1811   UATMP  2009        2   01-Apr-09             00:00      24 HOURS
# 1812   UATMP  2009        1   26-Mar-09             00:00      24 HOURS
#
#       SAMPLE_VALUE_REPORTED  AQS_UNIT_CODE          UNIT_DESC  \
# 1808                  0.514              8  PARTS PER BILLION
# 1809                  0.339              8  PARTS PER BILLION
# 1810                  0.300              8  PARTS PER BILLION
# 1811                  0.421              8  PARTS PER BILLION
# 1812                  2.100              8  PARTS PER BILLION
#
#      SAMPLING_FREQUENCY_CODE  SAMPLE_VALUE_STD_FINAL_UG_M3  \
# 1808                       6                      1.642159
# ...

# %%
benzene_daily['PROGRAM'].value_counts()
# Out:
# UATMP                           3116
# SLAMS                            689
# PAMS                             156
# SPECIAL PURPOSE                   95
# OTHER                             79
# SCHOOL AIR TOXICS MONITORING      51
# Name: PROGRAM, dtype: int64

# %%
benzene_three = benzene_clean[benzene_clean['DURATION_DESC'] == '3 HOURS']
benzene_three.head()
# Out:
#      PROGRAM  YEAR  QUARTER SAMPLE_DATE SAMPLE_START_TIME DURATION_DESC  \
# 2373   OTHER  1993        3   27-Aug-93             05:00       3 HOURS
# 2375   OTHER  1996        3   23-Jul-96             06:00       3 HOURS
# 2376   OTHER  1996        3   12-Jul-96             06:00       3 HOURS
# 2377   OTHER  1996        2   28-Jun-96             06:00       3 HOURS
# 2378   OTHER  1994        4   13-Oct-94             05:00       3 HOURS
#
#       SAMPLE_VALUE_REPORTED  AQS_UNIT_CODE                   UNIT_DESC  \
# 2373                  28.89             78  PARTS PER BILLION - CARBON
# 2375                   2.84             78  PARTS PER BILLION - CARBON
# 2376                   4.82             78  PARTS PER BILLION - CARBON
# 2377                   5.77             78  PARTS PER BILLION - CARBON
# 2378                  34.09             78  PARTS PER BILLION - CARBON
#
#      SAMPLING_FREQUENCY_CODE  SAMPLE_VALUE_STD_FINAL_UG_M3  \
# ...

# %%
benzene_three['PROGRAM'].value_counts()
# Out:
# OTHER    176
# Name: PROGRAM, dtype: int64

# %%
year_group = benzene_clean.groupby(by='YEAR')

# %%
year_group['SAMPLE_VALUE_STD_FINAL_UG_M3'].mean()
# Out:
# YEAR
# 1990    3.847527
# 1991    3.245165
# 1992    4.663434
# 1993    3.420350
# 1994    4.043942
# 1995    0.742762
# 1996    0.898580
# 1997    0.968244
# 1998    0.839327
# 1999    0.722443
# 2000    0.682980
# 2001    0.675213
# 2002    0.615717
# 2003    0.680170
# 2004    0.574209
# 2005    0.525133
# 2006    0.461789
# 2007    0.406142
# 2008    0.506511
# 2009    0.307327
# 2010    0.291549
# 2011    0.252588
# 2012    0.242723
# 2013    0.237689
# 2014    0.236264
# 2015    0.423141
# 2016    0.798671
# Name: SAMPLE_VALUE_STD_FINAL_UG_M3, dtype: float64

# %%
year_list = year_group['YEAR'].unique()
# year_list

# %%
plt.figure(figsize=(15,10))
plt.bar(year_list,year_group['SAMPLE_VALUE_REPORTED'].mean(), alpha=0.7)
plt.xlim(1989,2017)
plt.title('Sample Reported Mean by Year', size=20)
plt.xlabel('Year', size=16)
plt.ylabel('Sample Value Mean', size=16)
# Out:
# Text(0, 0.5, 'Sample Value Mean')

# %%
plt.figure(figsize=(15,10))
plt.bar(year_list,year_group['SAMPLE_VALUE_STD_FINAL_UG_M3'].mean(), alpha=0.7)
plt.xlim(1989,2017)
plt.title('Sample Final Mean by Year (microg/c3))', size=20)
plt.xlabel('Year', size=16)
plt.ylabel('Sample Value Mean', size=16)
# Out:
# Text(0, 0.5, 'Sample Value Mean')

# %%
latitude_group = benzene_clean.groupby(by="MONITOR_LATITUDE")

# %%
latitude_group['SAMPLE_VALUE_STD_FINAL_UG_M3'].mean()
# Out:
# MONITOR_LATITUDE
# 39.837090    1.068948
# 39.923042    0.994501
# 39.934446    0.756511
# 40.283092    0.480158
# 40.462182    0.407624
# 40.472825    0.770077
# 40.598028    3.616111
# 40.601725    4.675411
# 40.641440    1.292805
# 40.652053    1.051400
# 40.670250    0.789630
# 40.720989    0.662322
# 40.726668    3.263275
# 40.787628    0.557511
# 40.853579    0.642609
# 40.915747    0.227006
# 40.918381    0.767175
# 40.927458    0.184154
# Name: SAMPLE_VALUE_STD_FINAL_UG_M3, dtype: float64

# %%
latitude_list = latitude_group['MONITOR_LATITUDE'].unique()
latitude_list
# Out:
# MONITOR_LATITUDE
# 39.837090              [39.83709]
# 39.923042    [39.923041999999995]
# 39.934446             [39.934446]
# 40.283092    [40.283091999999996]
# 40.462182             [40.462182]
# 40.472825             [40.472825]
# 40.598028             [40.598028]
# 40.601725             [40.601725]
# 40.641440              [40.64144]
# 40.652053             [40.652053]
# 40.670250              [40.67025]
# 40.720989             [40.720989]
# 40.726668             [40.726668]
# 40.787628    [40.787628000000005]
# 40.853579    [40.853578999999996]
# 40.915747    [40.915746999999996]
# 40.918381             [40.918381]
# 40.927458             [40.927458]
# Name: MONITOR_LATITUDE, dtype: object

# %%
plt.figure(figsize=(20,10))
plt.bar(latitude_list, latitude_group['SAMPLE_VALUE_REPORTED'].mean(), edgecolor='k', width =0.1, align='center', alpha=0.5)
plt.title('Sample Reported Mean by Latitude', size=20)
plt.xlabel('Latitude', size=16)
plt.ylabel('Sample value reported mean', size=16)
plt.xlim(39.75,41)
# Out:
# (39.75, 41)

# %%
plt.figure(figsize=(20,10))
plt.bar(latitude_list, latitude_group['SAMPLE_VALUE_STD_FINAL_UG_M3'].mean(), edgecolor='k', width =0.05, align='center', alpha=0.5)
plt.title('Sample Final Mean by Latitude (microg/c3)', size=20)
plt.xlabel('Latitude', size=16)
plt.ylabel('Sample value reported mean', size=16)
plt.xlim(39.75,41)
# Out:
# (39.75, 41)

# %%
# benzene_clean[['Day','Month','Year Abbrev']] = benzene_clean['SAMPLE_DATE'].str.split('-')
benzene_clean['Day'], benzene_clean['Month'], benzene_clean['Year Abbrev'] = benzene_clean['SAMPLE_DATE'].str.split('-', 2).str
benzene_clean.head()
# Out:
#   PROGRAM  YEAR  QUARTER SAMPLE_DATE SAMPLE_START_TIME DURATION_DESC  \
# 0   SLAMS  2016        3   16-Sep-16             17:00        1 HOUR
# 1   SLAMS  2016        3   18-Sep-16             15:00        1 HOUR
# 2   SLAMS  2016        3   17-Sep-16             07:00        1 HOUR
# 3   SLAMS  2016        3   17-Sep-16             06:00        1 HOUR
# 4   SLAMS  2016        3   17-Sep-16             05:00        1 HOUR
#
#    SAMPLE_VALUE_REPORTED  AQS_UNIT_CODE          UNIT_DESC  \
# 0                  0.139              8  PARTS PER BILLION
# 1                  0.384              8  PARTS PER BILLION
# 2                  0.904              8  PARTS PER BILLION
# 3                  0.814              8  PARTS PER BILLION
# 4                  0.484              8  PARTS PER BILLION
#
#   SAMPLING_FREQUENCY_CODE  SAMPLE_VALUE_STD_FINAL_UG_M3  \
# 0                       1                      0.456957
# 1                       1                      1.214223
# ...

# %%
month_group = benzene_clean.groupby('Month')
month_group['SAMPLE_VALUE_STD_FINAL_UG_M3'].mean()
# Out:
# Month
# Apr    0.772463
# Aug    0.601456
# Dec    1.120478
# Feb    1.267400
# Jan    1.449801
# Jul    0.588440
# Jun    0.581206
# Mar    1.109304
# May    0.790647
# Nov    1.093993
# Oct    0.898026
# Sep    0.770132
# Name: SAMPLE_VALUE_STD_FINAL_UG_M3, dtype: float64

# %%
month_list = ['Apr','Aug','Dec','Feb','Jan','Jul','Jun','Mar','May','Nov','Oct','Sep']
month_list
# Out:
# ['Apr',
#  'Aug',
#  'Dec',
#  'Feb',
#  'Jan',
#  'Jul',
#  'Jun',
#  'Mar',
#  'May',
#  'Nov',
#  'Oct',
#  'Sep']

# %%
plt.figure(figsize=(15,10))
plt.bar(month_list,month_group['SAMPLE_VALUE_REPORTED'].mean(), alpha=0.7)
# plt.xlim(1989,2017)
plt.title('Sample Reported Mean by Month', size=20)
plt.xlabel('Month', size=16)
plt.ylabel('Sample Value Mean', size=16)
# Out:
# Text(0, 0.5, 'Sample Value Mean')

# %%
plt.figure(figsize=(15,10))
plt.bar(month_list,month_group['SAMPLE_VALUE_STD_FINAL_UG_M3'].mean(), alpha=0.7)
# plt.xlim(1989,2017)
plt.title('Sample Final Mean by Month (microg/c3)', size=20)
plt.xlabel('Month', size=16)
plt.ylabel('Sample Value Mean', size=16)
# Out:
# Text(0, 0.5, 'Sample Value Mean')

# %%
longitude_group = benzene_clean.groupby(by = 'MONITOR_LONGITUDE')
longitude_list = longitude_group['MONITOR_LONGITUDE'].unique()
longitude_list
# Out:
# MONITOR_LONGITUDE
# -75.244010     [-75.24401]
# -75.125291    [-75.125291]
# -75.097617    [-75.097617]
# -74.742644    [-74.742644]
# -74.676301    [-74.676301]
# -74.453808    [-74.453808]
# -74.441067    [-74.441067]
# -74.429439    [-74.429439]
# -74.422403    [-74.422403]
# -74.208365    [-74.208365]
# -74.199861    [-74.199861]
# -74.192892    [-74.192892]
# -74.176733    [-74.176733]
# -74.168092    [-74.168092]
# -74.160611    [-74.160611]
# -74.143741    [-74.143741]
# -74.126081    [-74.126081]
# -73.966212    [-73.966212]
# Name: MONITOR_LONGITUDE, dtype: object

# %%
coordinates = []
    
for index, row in benzene_clean.iterrows(): 
    if (row['MONITOR_LATITUDE'], row['MONITOR_LONGITUDE']) not in coordinates:
        coordinates.append((row['MONITOR_LATITUDE'],row['MONITOR_LONGITUDE']))
coordinates
# Out:
# [(40.64144, -74.208365),
#  (40.601725, -74.441067),
#  (40.652053, -74.199861),
#  (40.598028, -74.453808),
#  (40.462182, -74.429439),
#  (40.283091999999996, -74.742644),
#  (40.472825, -74.422403),
#  (39.923041999999995, -75.097617),
#  (40.720989, -74.192892),
#  (40.67025, -74.126081),
#  (40.726668, -74.143741),
#  (39.83709, -75.24401),
#  (40.915746999999996, -74.176733),
#  (40.927458, -74.160611),
#  (40.918381, -74.168092),
#  (40.787628000000005, -74.676301),
#  (39.934446, -75.125291),
#  (40.853578999999996, -73.966212)]

# %%
cities = []
for coordinate_pair in coordinates:
    lat, lon = coordinate_pair
    cities.append(citipy.nearest_city(lat, lon))
cities

# %%
city_names = []
for city in cities:
    city_names.append(city.city_name)
city_names
# Out:
# ['elizabeth',
#  'north plainfield',
#  'elizabeth',
#  'north plainfield',
#  'new brunswick',
#  'ewing',
#  'highland park',
#  'camden',
#  'newark',
#  'bayonne',
#  'harrison',
#  'darby',
#  'paterson',
#  'paterson',
#  'paterson',
#  'hopatcong',
#  'camden',
#  'fort lee']

# %%
city_data = pd.DataFrame({'Coordinates':coordinates,'City Name': city_names})
city_data
# Out:
#                          Coordinates         City Name
# 0             (40.64144, -74.208365)         elizabeth
# 1            (40.601725, -74.441067)  north plainfield
# 2            (40.652053, -74.199861)         elizabeth
# 3            (40.598028, -74.453808)  north plainfield
# 4            (40.462182, -74.429439)     new brunswick
# 5   (40.283091999999996, -74.742644)             ewing
# 6            (40.472825, -74.422403)     highland park
# 7   (39.923041999999995, -75.097617)            camden
# 8            (40.720989, -74.192892)            newark
# 9             (40.67025, -74.126081)           bayonne
# 10           (40.726668, -74.143741)          harrison
# 11             (39.83709, -75.24401)             darby
# 12  (40.915746999999996, -74.176733)          paterson
# 13           (40.927458, -74.160611)          paterson
# 14           (40.918381, -74.168092)          paterson
# 15  (40.787628000000005, -74.676301)         hopatcong
# ...

# %%
city_data['Coordinates'][0][0]
# Out:
# 40.64144

# %%
city_index = []
for index, row in benzene_clean.iterrows():
    for cindex, crow in city_data.iterrows():
        if crow['Coordinates'][1] == row['MONITOR_LONGITUDE']:
            city_index.append(crow['City Name'])
            continue
            
benzene_clean['City'] = city_index            
benzene_clean.head()
# Out:
#   PROGRAM  YEAR  QUARTER SAMPLE_DATE SAMPLE_START_TIME DURATION_DESC  \
# 0   SLAMS  2016        3   16-Sep-16             17:00        1 HOUR
# 1   SLAMS  2016        3   18-Sep-16             15:00        1 HOUR
# 2   SLAMS  2016        3   17-Sep-16             07:00        1 HOUR
# 3   SLAMS  2016        3   17-Sep-16             06:00        1 HOUR
# 4   SLAMS  2016        3   17-Sep-16             05:00        1 HOUR
#
#    SAMPLE_VALUE_REPORTED  AQS_UNIT_CODE          UNIT_DESC  \
# 0                  0.139              8  PARTS PER BILLION
# 1                  0.384              8  PARTS PER BILLION
# 2                  0.904              8  PARTS PER BILLION
# 3                  0.814              8  PARTS PER BILLION
# 4                  0.484              8  PARTS PER BILLION
#
#   SAMPLING_FREQUENCY_CODE  ...  SAMPLE_VALUE_STD_FINAL_TYPE MDL_STD_UG_M3  \
# 0                       1  ...                            L      0.319486
# ...

# %%
city_group = benzene_clean.groupby('City')
city_group['SAMPLE_VALUE_STD_FINAL_UG_M3'].mean()
# Out:
# City
# bayonne             0.789630
# camden              0.944523
# darby               1.068948
# elizabeth           1.292370
# ewing               0.480158
# fort lee            0.642609
# harrison            3.263275
# highland park       0.770077
# hopatcong           0.557511
# new brunswick       0.407624
# newark              0.662322
# north plainfield    4.350398
# paterson            0.464650
# Name: SAMPLE_VALUE_STD_FINAL_UG_M3, dtype: float64

# %%
city_list = city_group['City'].value_counts()
city_list
city_list = ['Bayonne', 'Camden', 'Darby','Elizabeth','Ewing','Fort Lee','Harrison','Highland Park','Hopcatong','New Brunswick','Newark','North Plainfield','Paterson']

# %%
plt.figure(figsize=(15,10))
plt.bar(city_list,city_group['SAMPLE_VALUE_STD_FINAL_UG_M3'].mean(), alpha=0.7)
# plt.xlim(1989,2017)
plt.title('Sample Final Mean by City (microg/c3)', size=20)
plt.xlabel('City', size=16)
plt.xticks(rotation=45)
plt.ylabel('Sample Value Mean', size=16)
# Out:
# Text(0, 0.5, 'Sample Value Mean')

# %%
city_year_group = benzene_clean.groupby(by=['YEAR', 'City'])
city_year_group['SAMPLE_VALUE_STD_FINAL_UG_M3'].max()
# Out:
# YEAR  City
# 1990  camden              11.533454
#       harrison             7.156492
#       north plainfield     9.584588
# 1991  camden               9.328999
#       harrison             7.987156
#                             ...
# 2016  elizabeth           13.761579
#       fort lee             6.492008
#       hopatcong            0.728429
#       new brunswick        1.916918
#       newark               8.358190
# Name: SAMPLE_VALUE_STD_FINAL_UG_M3, Length: 133, dtype: float64

# %%
city_year_df = pd.DataFrame(city_year_group['SAMPLE_VALUE_STD_FINAL_UG_M3'].max())
city_year_df
# Out:
#                        SAMPLE_VALUE_STD_FINAL_UG_M3
# YEAR City
# 1990 camden                               11.533454
#      harrison                              7.156492
#      north plainfield                      9.584588
# 1991 camden                                9.328999
#      harrison                              7.987156
# ...                                             ...
# 2016 elizabeth                            13.761579
#      fort lee                              6.492008
#      hopatcong                             0.728429
#      new brunswick                         1.916918
#      newark                                8.358190
#
# [133 rows x 1 columns]

# %%
city_year_df.query('City == [\'hopatcong\']')
# Out:
#                 SAMPLE_VALUE_STD_FINAL_UG_M3
# YEAR City
# 2001 hopatcong                      2.012763
# 2002 hopatcong                      1.980815
# 2003 hopatcong                      1.437688
# 2004 hopatcong                      1.661329
# 2005 hopatcong                      1.565483
# 2006 hopatcong                      1.118202
# 2007 hopatcong                      1.086253
# 2008 hopatcong                      2.322665
# 2009 hopatcong                      2.214040
# 2010 hopatcong                      0.961654
# 2011 hopatcong                      2.070271
# 2012 hopatcong                      2.341834
# 2013 hopatcong                      2.878571
# 2014 hopatcong                      1.316283
# 2015 hopatcong                      0.830664
# 2016 hopatcong                      0.728429

# %%
city_year_df.query('YEAR == 2008')
# Out:
#                     SAMPLE_VALUE_STD_FINAL_UG_M3
# YEAR City
# 2008 camden                            16.506790
#      elizabeth                         34.185029
#      ewing                              1.757174
#      highland park                      1.677303
#      hopatcong                          2.322665
#      new brunswick                      1.277945

# %%
city_year_mean = pd.DataFrame(city_year_group['SAMPLE_VALUE_STD_FINAL_UG_M3'].mean())
city_year_mean
# Out:
#                        SAMPLE_VALUE_STD_FINAL_UG_M3
# YEAR City
# 1990 camden                                4.219280
#      harrison                              2.939274
#      north plainfield                      3.475300
# 1991 camden                                3.394541
#      harrison                              5.281108
# ...                                             ...
# 2016 elizabeth                             1.291118
#      fort lee                              0.642609
#      hopatcong                             0.339812
#      new brunswick                         0.171683
#      newark                                0.662322
#
# [133 rows x 1 columns]

# %%
benzene_hourly.head()
# Out:
#   PROGRAM  YEAR  QUARTER SAMPLE_DATE SAMPLE_START_TIME DURATION_DESC  \
# 0   SLAMS  2016        3   16-Sep-16             17:00        1 HOUR
# 1   SLAMS  2016        3   18-Sep-16             15:00        1 HOUR
# 2   SLAMS  2016        3   17-Sep-16             07:00        1 HOUR
# 3   SLAMS  2016        3   17-Sep-16             06:00        1 HOUR
# 4   SLAMS  2016        3   17-Sep-16             05:00        1 HOUR
#
#    SAMPLE_VALUE_REPORTED  AQS_UNIT_CODE          UNIT_DESC  \
# 0                  0.139              8  PARTS PER BILLION
# 1                  0.384              8  PARTS PER BILLION
# 2                  0.904              8  PARTS PER BILLION
# 3                  0.814              8  PARTS PER BILLION
# 4                  0.484              8  PARTS PER BILLION
#
#   SAMPLING_FREQUENCY_CODE  SAMPLE_VALUE_STD_FINAL_UG_M3  \
# 0                       1                      0.456957
# 1                       1                      1.214223
# ...

# %%
benzene_daily['PROGRAM'].value_counts()
# Out:
# UATMP                           3116
# SLAMS                            689
# PAMS                             156
# SPECIAL PURPOSE                   95
# OTHER                             79
# SCHOOL AIR TOXICS MONITORING      51
# Name: PROGRAM, dtype: int64

# %%
program_group = benzene_clean.groupby(by='PROGRAM')
program_group['SAMPLE_VALUE_STD_FINAL_UG_M3'].max()
# Out:
# PROGRAM
# OTHER                           18.152144
# PAMS                            23.428992
# SCHOOL AIR TOXICS MONITORING     1.916918
# SLAMS                           13.761579
# SPECIAL PURPOSE                  0.831197
# UATMP                           34.185029
# Name: SAMPLE_VALUE_STD_FINAL_UG_M3, dtype: float64

# %%
program_city_group = benzene_clean.groupby(by=['PROGRAM','City', 'YEAR'])
program_city_group['SAMPLE_VALUE_STD_FINAL_UG_M3'].max()
program_city_df = pd.DataFrame(program_city_group['SAMPLE_VALUE_STD_FINAL_UG_M3'].max())
program_city_mean = pd.DataFrame(program_city_group['SAMPLE_VALUE_STD_FINAL_UG_M3'].mean())

# %%
program_city_mean.query('City == ["paterson"]')
# Out:
#                                SAMPLE_VALUE_STD_FINAL_UG_M3
# PROGRAM         City     YEAR
# SLAMS           paterson 2005                      0.257985
#                          2006                      0.304094
#                          2010                      1.420047
# SPECIAL PURPOSE paterson 2005                      0.219487
#                          2006                      0.205998
# UATMP           paterson 2011                      1.222158

# %%
program_city_mean.plot(kind='bar', figsize=(15,10))

# %%
elizabeth = pd.DataFrame(city_year_mean.query('City == [\'elizabeth\']'))
elizabeth
# Out:
#                 SAMPLE_VALUE_STD_FINAL_UG_M3
# YEAR City
# 2000 elizabeth                      1.904630
# 2001 elizabeth                      1.976821
# 2002 elizabeth                      1.815844
# 2003 elizabeth                      1.634383
# 2004 elizabeth                      1.493066
# 2005 elizabeth                      1.590509
# 2006 elizabeth                      1.294966
# 2007 elizabeth                      1.089029
# 2008 elizabeth                      1.831899
# 2009 elizabeth                      1.296590
# 2010 elizabeth                      1.038588
# 2011 elizabeth                      1.018585
# 2012 elizabeth                      1.039483
# 2013 elizabeth                      0.802958
# 2014 elizabeth                      0.782525
# 2015 elizabeth                      0.817938
# 2016 elizabeth                      1.291118

# %%
elizabeth.plot(kind='bar')

# %%
camden = pd.DataFrame(city_year_mean.query('City == [\'camden\']'))
camden
# Out:
#              SAMPLE_VALUE_STD_FINAL_UG_M3
# YEAR City
# 1990 camden                      4.219280
# 1991 camden                      3.394541
# 1992 camden                      3.359930
# 1993 camden                      2.745300
# 1994 camden                      3.070263
# 1995 camden                      1.297606
# 1996 camden                      2.376486
# 1997 camden                      1.443910
# 1998 camden                      1.258678
# 1999 camden                      1.003287
# 2000 camden                      1.005748
# 2001 camden                      1.044674
# 2002 camden                      0.893389
# 2003 camden                      1.119221
# 2004 camden                      0.985829
# 2005 camden                      0.797885
# 2006 camden                      0.769173
# 2007 camden                      0.669265
# 2008 camden                      0.685958
# 2013 camden                      0.852244
# 2014 camden                      0.753830
# ...

# %%
camden.plot(kind='bar', color='black')

# %%
hopatcong = pd.DataFrame(city_year_mean.query('City == [\'hopatcong\']'))
hopatcong
# Out:
#                 SAMPLE_VALUE_STD_FINAL_UG_M3
# YEAR City
# 2001 hopatcong                      0.769762
# 2002 hopatcong                      0.840687
# 2003 hopatcong                      0.702511
# 2004 hopatcong                      0.665877
# 2005 hopatcong                      0.652391
# 2006 hopatcong                      0.502971
# 2007 hopatcong                      0.470382
# 2008 hopatcong                      0.590995
# 2009 hopatcong                      0.529981
# 2010 hopatcong                      0.473905
# 2011 hopatcong                      0.524481
# 2012 hopatcong                      0.635359
# 2013 hopatcong                      0.490490
# 2014 hopatcong                      0.468545
# 2015 hopatcong                      0.396628
# 2016 hopatcong                      0.339812

# %%
hopatcong.plot(kind='bar', color='purple')

# %%
new_brunswick = pd.DataFrame(city_year_mean.query('City == [\'new brunswick\']'))
new_brunswick
# Out:
#                     SAMPLE_VALUE_STD_FINAL_UG_M3
# YEAR City
# 1996 new brunswick                      0.900511
# 1997 new brunswick                      0.859434
# 1998 new brunswick                      0.640787
# 1999 new brunswick                      0.564620
# 2000 new brunswick                      0.529116
# 2001 new brunswick                      0.483365
# 2002 new brunswick                      0.445044
# 2003 new brunswick                      0.470363
# 2004 new brunswick                      0.371331
# 2005 new brunswick                      0.344275
# 2006 new brunswick                      0.305099
# 2007 new brunswick                      0.287481
# 2008 new brunswick                      0.296178
# 2009 new brunswick                      0.253406
# 2010 new brunswick                      0.240164
# 2011 new brunswick                      0.182034
# 2012 new brunswick                      0.178170
# 2013 new brunswick                      0.183551
# ...

# %%
new_brunswick.plot(kind='bar', color='red')

# %%
harrison = pd.DataFrame(city_year_mean.query('City == [\'harrison\']'))
harrison
# Out:
#                SAMPLE_VALUE_STD_FINAL_UG_M3
# YEAR City
# 1990 harrison                      2.939274
# 1991 harrison                      5.281108
# 1992 harrison                      3.180663
# 1993 harrison                      3.089255
# 1994 harrison                      4.332766
# 1995 harrison                      2.405613
# 1996 harrison                      3.697927
# 1997 harrison                      3.421698
# 1999 harrison                      2.295509

# %%
harrison.plot(kind='bar',color='yellow')

# %%
ewing = pd.DataFrame(city_year_mean.query('City == [\'ewing\']'))
ewing
# Out:
#             SAMPLE_VALUE_STD_FINAL_UG_M3
# YEAR City
# 1995 ewing                      0.699019
# 1996 ewing                      0.803724
# 1997 ewing                      0.631805
# 1998 ewing                      0.622826
# 1999 ewing                      0.577144
# 2000 ewing                      0.500314
# 2001 ewing                      0.458874
# 2002 ewing                      0.467207
# 2003 ewing                      0.468912
# 2004 ewing                      0.364337
# 2005 ewing                      0.362214
# 2006 ewing                      0.340362
# 2007 ewing                      0.283926
# 2008 ewing                      0.360178
# 2009 ewing                      0.309135
# 2010 ewing                      0.285273

# %%
ewing.plot(kind='bar', color='green')

# %% [markdown]
# Elizabeth, Camden, Hopatcong, New Brunswick, Harrison,Ewing, Highland Park

# %%
highland_park = pd.DataFrame(city_year_mean.query('City == [\'highland park\']'))
highland_park
# Out:
#                     SAMPLE_VALUE_STD_FINAL_UG_M3
# YEAR City
# 2001 highland park                      1.028568
# 2002 highland park                      1.125575
# 2003 highland park                      1.050233
# 2004 highland park                      0.970173
# 2005 highland park                      0.991360
# 2006 highland park                      0.676121
# 2007 highland park                      0.556705
# 2008 highland park                      0.692007
# 2009 highland park                      0.687128
# 2010 highland park                      0.650532
# 2011 highland park                      0.707552
# 2012 highland park                      0.864636
# 2013 highland park                      0.649657
# 2014 highland park                      0.535086
# 2015 highland park                      0.528127

# %%
highland_park.plot(kind='bar', color='gray')

# %%
fig, axes = plt.subplots(nrows=2, ncols=3, figsize=(20,10))

elizabeth.plot(kind='bar', ax=axes[0,0], legend=False)
axes[0,0].set_title("Elizabeth")

camden.plot(kind='bar', color='black', ax=axes[0,1], legend=False)
axes[0,1].set_title("Camden")

hopatcong.plot(kind='bar', color='red', ax=axes[0,2], legend=False)
axes[0,2].set_title("Hopatcong")

new_brunswick.plot(kind='bar', color = 'yellow', ax=axes[1,0], legend=False)
axes[1,0].set_title("New Brunswick")

harrison.plot(kind='bar', color='gray', ax=axes[1,1], legend=False)
axes[1,1].set_title("Harrison")

ewing.plot(kind='bar', color='purple', ax=axes[1,2], legend=False)
axes[1,2].set_title("Ewing")

fig.subplots_adjust(hspace=1.5)
