# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
import json
import requests
from config import api_key
from config import email
import pandas as pd
import numpy as np

# %%
toluene = pd.read_csv("Database/Toluene/Toluene.csv")
toluene.head()
# Out:
# C:\Users\jjjjj\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3058: DtypeWarning: Columns (15,24,25,39) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#   STATE_ABBR  AMA_SITE_CODE  AQS_POC PROGRAM  YEAR  QUARTER SAMPLE_DATE  \
# 0         NJ      340390004        1   SLAMS  2016        3   17-Sep-16
# 1         NJ      340390004        1   SLAMS  2016        3   17-Sep-16
# 2         NJ      340390004        1   SLAMS  2016        3   18-Sep-16
# 3         NJ      340390004        1   SLAMS  2016        3   18-Sep-16
# 4         NJ      340390004        1   SLAMS  2016        3   18-Sep-16
#
#   SAMPLE_START_TIME  AQS_PARAMETER_CODE AQS_PARAMETER_NAME  ...  \
# 0             18:00               45202            Toluene  ...
# 1             05:00               45202            Toluene  ...
# 2             09:00               45202            Toluene  ...
# 3             08:00               45202            Toluene  ...
# 4             07:00               45202            Toluene  ...
#
#   AQS_QUALIFIER_10 AQS_METHOD_CODE  SAMPLE_COLLECTION_DESC  \
# 0              NaN              92           Tenax/GR/Trap
# 1              NaN              92           Tenax/GR/Trap
# 2              NaN              92           Tenax/GR/Trap
# 3              NaN              92           Tenax/GR/Trap
# 4              NaN              92           Tenax/GR/Trap
#
#       SAMPLE_ANALYSIS_DESC SAMPLE_VALUE_FLAG BELOW_MDL_FLAG  CENSUS_TRACT_ID  \
# 0  Thermal Desorber GC/PID               NaN            NaN      34039030600
# 1  Thermal Desorber GC/PID               NaN            NaN      34039030600
# 2  Thermal Desorber GC/PID               NaN            NaN      34039030600
# 3  Thermal Desorber GC/PID               NaN            NaN      34039030600
# 4  Thermal Desorber GC/PID               NaN            NaN      34039030600
#
#    CENSUS_TRACT_POPULATION_2010 MONITOR_LATITUDE  MONITOR_LONGITUDE
# 0                          3685         40.64144         -74.208365
# 1                          3685         40.64144         -74.208365
# 2                          3685         40.64144         -74.208365
# 3                          3685         40.64144         -74.208365
# 4                          3685         40.64144         -74.208365
#
# [5 rows x 44 columns]

# %%
columns = 'PROGRAM', 'CENSUS_TRACT_POPULATION_2010', 'MONITOR_LATITUDE', 'MONITOR_LONGITUDE', 'YEAR', 'QUARTER','SAMPLE_DATE', 'SAMPLE_START_TIME', 'DATA_SOURCE', 'DURATION_DESC', 'SAMPLE_VALUE_REPORTED', 'UNIT_DESC', 'AQS_UNIT_CODE', 'SAMPLING_FREQUENCY_CODE', 'SAMPLE_VALUE_STD_FINAL_UG_M3','SAMPLE_VALUE_STD_FINAL_TYPE', 'MDL_STD_UG_M3','MDL_TYPE', 'AQS_METHOD_CODE', 'SAMPLE_COLLECTION_DESC', 'SAMPLE_ANALYSIS_DESC'
toluene_clean = toluene.filter(items=columns)
toluene_clean.head()
# Out:
#   PROGRAM  CENSUS_TRACT_POPULATION_2010  MONITOR_LATITUDE  MONITOR_LONGITUDE  \
# 0   SLAMS                          3685          40.64144         -74.208365
# 1   SLAMS                          3685          40.64144         -74.208365
# 2   SLAMS                          3685          40.64144         -74.208365
# 3   SLAMS                          3685          40.64144         -74.208365
# 4   SLAMS                          3685          40.64144         -74.208365
#
#    YEAR  QUARTER SAMPLE_DATE SAMPLE_START_TIME   DATA_SOURCE DURATION_DESC  \
# 0  2016        3   17-Sep-16             18:00  AQS_20171121        1 HOUR
# 1  2016        3   17-Sep-16             05:00  AQS_20171121        1 HOUR
# 2  2016        3   18-Sep-16             09:00  AQS_20171121        1 HOUR
# 3  2016        3   18-Sep-16             08:00  AQS_20171121        1 HOUR
# 4  2016        3   18-Sep-16             07:00  AQS_20171121        1 HOUR
#
#    ...          UNIT_DESC AQS_UNIT_CODE  SAMPLING_FREQUENCY_CODE  \
# 0  ...  PARTS PER BILLION             8                        1
# 1  ...  PARTS PER BILLION             8                        1
# 2  ...  PARTS PER BILLION             8                        1
# 3  ...  PARTS PER BILLION             8                        1
# 4  ...  PARTS PER BILLION             8                        1
#
#   SAMPLE_VALUE_STD_FINAL_UG_M3  SAMPLE_VALUE_STD_FINAL_TYPE MDL_STD_UG_M3  \
# 0                     0.634496                            L      0.376857
# 1                     4.265894                            L      0.376857
# 2                     2.103553                            L      0.376857
# 3                     2.332506                            L      0.376857
# 4                     2.042216                            L      0.376857
#
#       MDL_TYPE AQS_METHOD_CODE  SAMPLE_COLLECTION_DESC  \
# 0  FEDERAL_MDL              92           Tenax/GR/Trap
# 1  FEDERAL_MDL              92           Tenax/GR/Trap
# 2  FEDERAL_MDL              92           Tenax/GR/Trap
# 3  FEDERAL_MDL              92           Tenax/GR/Trap
# 4  FEDERAL_MDL              92           Tenax/GR/Trap
#
#       SAMPLE_ANALYSIS_DESC
# 0  Thermal Desorber GC/PID
# 1  Thermal Desorber GC/PID
# 2  Thermal Desorber GC/PID
# 3  Thermal Desorber GC/PID
# 4  Thermal Desorber GC/PID
#
# [5 rows x 21 columns]

# %%
# First look at the data

print(f"program descript: {len(toluene_clean.PROGRAM.value_counts())} programs")
print(toluene_clean.PROGRAM.value_counts())
print()
print(f"duration descript:")
print(toluene_clean.DURATION_DESC.value_counts())
print()
print(f"total locations: lat-{toluene_clean.MONITOR_LATITUDE.value_counts().count()} / lon-{toluene_clean.MONITOR_LONGITUDE.value_counts().count()}")
print()
#print(f"checkout start times:")
#print(toluene_clean.SAMPLE_START_TIME.value_counts())
# Out:
# program descript: 6 programs
# PAMS                            92910
# SLAMS                           27433
# UATMP                            3116
# OTHER                             255
# SPECIAL PURPOSE                    95
# SCHOOL AIR TOXICS MONITORING       51
# Name: PROGRAM, dtype: int64
#
# duration descript:
# 1 HOUR      119498
# 24 HOURS      4186
# 3 HOURS        176
# Name: DURATION_DESC, dtype: int64
#
# total locations: lat-18 / lon-18

# %%
toluene_clean["SAMPLE_DATE"].dtype
# Out:
# dtype('O')

# %%
#toluene_clean["SAMPLE_DATE"] = pd.to_datetime(toluene_clean.SAMPLE_DATE)
#toluene_clean.head()

# %%
toluene_hourly = toluene_clean[toluene_clean['DURATION_DESC'] == '1 HOUR']
toluene_daily = toluene_clean[toluene_clean['DURATION_DESC'] == '24 HOUR']
toluene_three = toluene_clean[toluene_clean['DURATION_DESC'] == '3 HOUR']
# Out:
#        PROGRAM  CENSUS_TRACT_POPULATION_2010  MONITOR_LATITUDE  \
# 0        SLAMS                          3685         40.641440
# 1        SLAMS                          3685         40.641440
# 2        SLAMS                          3685         40.641440
# 3        SLAMS                          3685         40.641440
# 4        SLAMS                          3685         40.641440
# ...        ...                           ...               ...
# 123855   SLAMS                          2328         39.934446
# 123856   SLAMS                          2328         39.934446
# 123857   SLAMS                          2328         39.934446
# 123858   SLAMS                          2328         39.934446
# 123859   SLAMS                          2328         39.934446
#
#         MONITOR_LONGITUDE  YEAR  QUARTER SAMPLE_DATE SAMPLE_START_TIME  \
# 0              -74.208365  2016        3   17-Sep-16             18:00
# 1              -74.208365  2016        3   17-Sep-16             05:00
# 2              -74.208365  2016        3   18-Sep-16             09:00
# 3              -74.208365  2016        3   18-Sep-16             08:00
# 4              -74.208365  2016        3   18-Sep-16             07:00
# ...                   ...   ...      ...         ...               ...
# 123855         -75.125291  2016        4   14-Oct-16             16:00
# 123856         -75.125291  2016        4   14-Oct-16             15:00
# 123857         -75.125291  2016        4   14-Oct-16             14:00
# 123858         -75.125291  2016        4   13-Oct-16             14:00
# 123859         -75.125291  2016        4   15-Oct-16             00:00
#
#          DATA_SOURCE DURATION_DESC  ...          UNIT_DESC AQS_UNIT_CODE  \
# 0       AQS_20171121        1 HOUR  ...  PARTS PER BILLION             8
# 1       AQS_20171121        1 HOUR  ...  PARTS PER BILLION             8
# 2       AQS_20171121        1 HOUR  ...  PARTS PER BILLION             8
# 3       AQS_20171121        1 HOUR  ...  PARTS PER BILLION             8
# 4       AQS_20171121        1 HOUR  ...  PARTS PER BILLION             8
# ...              ...           ...  ...                ...           ...
# 123855  AQS_20171121        1 HOUR  ...  PARTS PER BILLION             8
# 123856  AQS_20171121        1 HOUR  ...  PARTS PER BILLION             8
# 123857  AQS_20171121        1 HOUR  ...  PARTS PER BILLION             8
# 123858  AQS_20171121        1 HOUR  ...  PARTS PER BILLION             8
# 123859  AQS_20171121        1 HOUR  ...  PARTS PER BILLION             8
#
#         SAMPLING_FREQUENCY_CODE SAMPLE_VALUE_STD_FINAL_UG_M3  \
# 0                             1                     0.634496
# 1                             1                     4.265894
# 2                             1                     2.103553
# 3                             1                     2.332506
# 4                             1                     2.042216
# ...                         ...                          ...
# 123855                        1                     0.851889
# 123856                        1                     0.672133
# 123857                        1                     0.855797
# 123858                        1                     2.177183
# 123859                        1                     9.800047
#
#         SAMPLE_VALUE_STD_FINAL_TYPE MDL_STD_UG_M3     MDL_TYPE  \
# 0                                 L      0.376857  FEDERAL_MDL
# 1                                 L      0.376857  FEDERAL_MDL
# 2                                 L      0.376857  FEDERAL_MDL
# 3                                 L      0.376857  FEDERAL_MDL
# 4                                 L      0.376857  FEDERAL_MDL
# ...                             ...           ...          ...
# 123855                            L      0.376857  FEDERAL_MDL
# 123856                            L      0.376857  FEDERAL_MDL
# 123857                            L      0.376857  FEDERAL_MDL
# 123858                            L      0.376857  FEDERAL_MDL
# 123859                            L      0.376857  FEDERAL_MDL
#
#        AQS_METHOD_CODE  SAMPLE_COLLECTION_DESC     SAMPLE_ANALYSIS_DESC
# 0                   92           Tenax/GR/Trap  Thermal Desorber GC/PID
# 1                   92           Tenax/GR/Trap  Thermal Desorber GC/PID
# 2                   92           Tenax/GR/Trap  Thermal Desorber GC/PID
# 3                   92           Tenax/GR/Trap  Thermal Desorber GC/PID
# 4                   92           Tenax/GR/Trap  Thermal Desorber GC/PID
# ...                ...                     ...                      ...
# 123855              92           Tenax/GR/Trap  Thermal Desorber GC/PID
# 123856              92           Tenax/GR/Trap  Thermal Desorber GC/PID
# 123857              92           Tenax/GR/Trap  Thermal Desorber GC/PID
# 123858              92           Tenax/GR/Trap  Thermal Desorber GC/PID
# 123859              92           Tenax/GR/Trap  Thermal Desorber GC/PID
#
# [119498 rows x 21 columns]

# %%
yearly = toluene_clean.groupby(by='YEAR')
year_group = yearly['SAMPLE_VALUE_STD_FINAL_UG_M3'].mean()
year_group_db = pd.DataFrame(year_group)
year_group_db
# Out:
#       SAMPLE_VALUE_STD_FINAL_UG_M3
# YEAR
# 1990                     10.865009
# 1991                     17.910314
# 1992                     17.469820
# 1993                     12.581520
# 1994                     13.681692
# 1995                      2.379641
# 1996                      4.041037
# 1997                      3.616655
# 1998                      3.285326
# 1999                      2.749267
# 2000                      2.643130
# 2001                      2.908448
# 2002                      2.148268
# 2003                      2.231783
# 2004                      5.983963
# 2005                      2.261997
# 2006                      1.470116
# 2007                      1.391729
# 2008                      1.598624
# 2009                      1.660722
# 2010                      0.929808
# 2011                      0.947460
# 2012                      1.041875
# 2013                      0.831404
# 2014                      0.678599
# 2015                      1.171501
# 2016                      2.307031

# %%
ax = year_group_db.plot.bar(rot=0, figsize=(10,5))
plt.xlabel('Years', size=10)
plt.ylabel('Value Mean', size=10)
plt.title('Standardized Mean by Year', size=12)
plt.grid(alpha=0.4)
plt.xticks(rotation=50)
plt.show()

# %%
latitude = toluene_clean.groupby(by='MONITOR_LATITUDE')
latitude_group = latitude['SAMPLE_VALUE_STD_FINAL_UG_M3'].mean()
latitude_group_db = pd.DataFrame(latitude_group)
latitude_group_db
# Out:
#                   SAMPLE_VALUE_STD_FINAL_UG_M3
# MONITOR_LATITUDE
# 39.837090                             2.372627
# 39.923042                             2.753091
# 39.934446                             2.810341
# 40.283092                             1.406715
# 40.462182                             3.098485
# 40.472825                             2.979197
# 40.598028                            18.624098
# 40.601725                            18.772494
# 40.641440                             2.973165
# 40.652053                             2.108342
# 40.670250                             2.686103
# 40.720989                             1.670011
# 40.726668                            16.516229
# 40.787628                             1.824185
# 40.853579                             1.720701
# 40.915747                             1.152255
# 40.918381                             4.128747
# 40.927458                             0.923239

# %%
ax = latitude_group_db.plot.bar(rot=0, figsize=(15,7))
plt.xlabel('Lats', size=8)
plt.ylabel('Value Mean', size=10)
plt.title('Standardized Mean by Year', size=12)
plt.grid(alpha=0.4)
plt.xticks(rotation=90)
plt.show()

# %%
#x_axis = toluene_clean["SAMPLE_DATE"]
#y = toluene_clean["SAMPLE_VALUE_STD_FINAL_UG_M3"]
    
#plt.plot(x_axis, y)
#plt.show()

#groupby_test = toluene_clean.groupby(["MONITOR_LATITUDE", "SAMPLE_DATE"])["SAMPLE_VALUE_STD_FINAL_UG_M3"]
#groupby_test2 = pd.DataFrame(groupby_test.mean())
#groupby_test2

# %%
#groupby_test = toluene_clean.groupby(["PROGRAM", "SAMPLE_DATE"])["SAMPLE_VALUE_STD_FINAL_UG_M3"]
#groupby_test2 = pd.DataFrame(groupby_test.mean())
#groupby_test2

# %%
#sem_test = groupby_test.sem()
#sem_test2 = pd.DataFrame(sem_test)
#sem_test2.head()
