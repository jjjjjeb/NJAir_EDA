# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
import json
#import requests
#from config import api_key
#from config import email
import pandas as pd
import numpy as np
from citipy import citipy

import gmaps
from config import gkey

# %%
# reading database

toluene = pd.read_csv("Database/Toluene/Toluene.csv")
toluene.head()
# Out:
# C:\Users\jjjjj\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3058: DtypeWarning: Columns (15,24,25,39) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#   STATE_ABBR  AMA_SITE_CODE  AQS_POC PROGRAM  YEAR  QUARTER SAMPLE_DATE  \
# 0         NJ      340390004        1   SLAMS  2016        3   17-Sep-16
# 1         NJ      340390004        1   SLAMS  2016        3   17-Sep-16
# 2         NJ      340390004        1   SLAMS  2016        3   18-Sep-16
# 3         NJ      340390004        1   SLAMS  2016        3   18-Sep-16
# 4         NJ      340390004        1   SLAMS  2016        3   18-Sep-16
#
#   SAMPLE_START_TIME  AQS_PARAMETER_CODE AQS_PARAMETER_NAME  ...  \
# 0             18:00               45202            Toluene  ...
# 1             05:00               45202            Toluene  ...
# 2             09:00               45202            Toluene  ...
# 3             08:00               45202            Toluene  ...
# 4             07:00               45202            Toluene  ...
#
#   AQS_QUALIFIER_10 AQS_METHOD_CODE  SAMPLE_COLLECTION_DESC  \
# 0              NaN              92           Tenax/GR/Trap
# 1              NaN              92           Tenax/GR/Trap
# 2              NaN              92           Tenax/GR/Trap
# 3              NaN              92           Tenax/GR/Trap
# 4              NaN              92           Tenax/GR/Trap
#
#       SAMPLE_ANALYSIS_DESC SAMPLE_VALUE_FLAG BELOW_MDL_FLAG  CENSUS_TRACT_ID  \
# 0  Thermal Desorber GC/PID               NaN            NaN      34039030600
# 1  Thermal Desorber GC/PID               NaN            NaN      34039030600
# 2  Thermal Desorber GC/PID               NaN            NaN      34039030600
# 3  Thermal Desorber GC/PID               NaN            NaN      34039030600
# 4  Thermal Desorber GC/PID               NaN            NaN      34039030600
#
#    CENSUS_TRACT_POPULATION_2010 MONITOR_LATITUDE  MONITOR_LONGITUDE
# 0                          3685         40.64144         -74.208365
# 1                          3685         40.64144         -74.208365
# 2                          3685         40.64144         -74.208365
# 3                          3685         40.64144         -74.208365
# 4                          3685         40.64144         -74.208365
#
# [5 rows x 44 columns]

# %%
# cleaning up unecesary columns

columns = 'PROGRAM', 'CENSUS_TRACT_POPULATION_2010', 'MONITOR_LATITUDE', 'MONITOR_LONGITUDE', 'YEAR', 'QUARTER','SAMPLE_DATE', 'SAMPLE_START_TIME', 'DATA_SOURCE', 'DURATION_DESC', 'SAMPLE_VALUE_REPORTED', 'UNIT_DESC', 'AQS_UNIT_CODE', 'SAMPLING_FREQUENCY_CODE', 'SAMPLE_VALUE_STD_FINAL_UG_M3','SAMPLE_VALUE_STD_FINAL_TYPE', 'MDL_STD_UG_M3','MDL_TYPE', 'AQS_METHOD_CODE', 'SAMPLE_COLLECTION_DESC', 'SAMPLE_ANALYSIS_DESC'
toluene_clean = toluene.filter(items=columns)
toluene_clean.head()
# Out:
#   PROGRAM  CENSUS_TRACT_POPULATION_2010  MONITOR_LATITUDE  MONITOR_LONGITUDE  \
# 0   SLAMS                          3685          40.64144         -74.208365
# 1   SLAMS                          3685          40.64144         -74.208365
# 2   SLAMS                          3685          40.64144         -74.208365
# 3   SLAMS                          3685          40.64144         -74.208365
# 4   SLAMS                          3685          40.64144         -74.208365
#
#    YEAR  QUARTER SAMPLE_DATE SAMPLE_START_TIME   DATA_SOURCE DURATION_DESC  \
# 0  2016        3   17-Sep-16             18:00  AQS_20171121        1 HOUR
# 1  2016        3   17-Sep-16             05:00  AQS_20171121        1 HOUR
# 2  2016        3   18-Sep-16             09:00  AQS_20171121        1 HOUR
# 3  2016        3   18-Sep-16             08:00  AQS_20171121        1 HOUR
# 4  2016        3   18-Sep-16             07:00  AQS_20171121        1 HOUR
#
#    ...          UNIT_DESC AQS_UNIT_CODE  SAMPLING_FREQUENCY_CODE  \
# 0  ...  PARTS PER BILLION             8                        1
# 1  ...  PARTS PER BILLION             8                        1
# 2  ...  PARTS PER BILLION             8                        1
# 3  ...  PARTS PER BILLION             8                        1
# 4  ...  PARTS PER BILLION             8                        1
#
#   SAMPLE_VALUE_STD_FINAL_UG_M3  SAMPLE_VALUE_STD_FINAL_TYPE MDL_STD_UG_M3  \
# 0                     0.634496                            L      0.376857
# 1                     4.265894                            L      0.376857
# 2                     2.103553                            L      0.376857
# 3                     2.332506                            L      0.376857
# 4                     2.042216                            L      0.376857
#
#       MDL_TYPE AQS_METHOD_CODE  SAMPLE_COLLECTION_DESC  \
# 0  FEDERAL_MDL              92           Tenax/GR/Trap
# 1  FEDERAL_MDL              92           Tenax/GR/Trap
# 2  FEDERAL_MDL              92           Tenax/GR/Trap
# 3  FEDERAL_MDL              92           Tenax/GR/Trap
# 4  FEDERAL_MDL              92           Tenax/GR/Trap
#
#       SAMPLE_ANALYSIS_DESC
# 0  Thermal Desorber GC/PID
# 1  Thermal Desorber GC/PID
# 2  Thermal Desorber GC/PID
# 3  Thermal Desorber GC/PID
# 4  Thermal Desorber GC/PID
#
# [5 rows x 21 columns]

# %%
# getting some basic information about the data

print(toluene_clean.info())
print(toluene_clean.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 123860 entries, 0 to 123859
# Data columns (total 21 columns):
# PROGRAM                         123860 non-null object
# CENSUS_TRACT_POPULATION_2010    123860 non-null int64
# MONITOR_LATITUDE                123860 non-null float64
# MONITOR_LONGITUDE               123860 non-null float64
# YEAR                            123860 non-null int64
# QUARTER                         123860 non-null int64
# SAMPLE_DATE                     123860 non-null object
# SAMPLE_START_TIME               123860 non-null object
# DATA_SOURCE                     123860 non-null object
# DURATION_DESC                   123860 non-null object
# SAMPLE_VALUE_REPORTED           123581 non-null float64
# UNIT_DESC                       123860 non-null object
# AQS_UNIT_CODE                   123860 non-null int64
# SAMPLING_FREQUENCY_CODE         123860 non-null object
# SAMPLE_VALUE_STD_FINAL_UG_M3    123581 non-null float64
# SAMPLE_VALUE_STD_FINAL_TYPE     123860 non-null object
# MDL_STD_UG_M3                   123860 non-null float64
# MDL_TYPE                        123860 non-null object
# AQS_METHOD_CODE                 123860 non-null int64
# SAMPLE_COLLECTION_DESC          123860 non-null object
# SAMPLE_ANALYSIS_DESC            123860 non-null object
# dtypes: float64(5), int64(5), object(11)
# memory usage: 19.8+ MB
# None
#        CENSUS_TRACT_POPULATION_2010  MONITOR_LATITUDE  MONITOR_LONGITUDE  \
# count                 123860.000000     123860.000000      123860.000000
# mean                    5675.032553         40.331333         -74.625181
# std                     1763.311738          0.271059           0.336472
# min                     1483.000000         39.837090         -75.244010
# 25%                     5231.000000         40.283092         -74.742644
# 50%                     5231.000000         40.462182         -74.676301
# 75%                     7932.000000         40.462182         -74.429439
# max                     7932.000000         40.927458         -73.966212
#
#                 YEAR        QUARTER  SAMPLE_VALUE_REPORTED  AQS_UNIT_CODE  \
# count  123860.000000  123860.000000          123581.000000  123860.000000
# mean     2006.235500       2.757153               3.568899      60.546343
# std         6.855916       0.607204              13.004770      30.284208
# min      1990.000000       1.000000               0.000000       8.000000
# 25%      2000.000000       2.000000               0.637000      78.000000
# 50%      2005.000000       3.000000               1.600000      78.000000
# 75%      2013.000000       3.000000               3.500000      78.000000
# max      2016.000000       4.000000            1509.000000      78.000000
#
#        SAMPLE_VALUE_STD_FINAL_UG_M3  MDL_STD_UG_M3  AQS_METHOD_CODE
# count                 123581.000000  123860.000000    123860.000000
# mean                       2.469374       0.090665       119.297626
# std                        7.220107       0.154528        15.137343
# min                        0.000000       0.005384        92.000000
# 25%                        0.646040       0.005384       101.000000
# 50%                        1.292080       0.005384       128.000000
# 75%                        2.530323       0.018843       128.000000
# max                      812.395340       0.376857       129.000000

# %%
# begining a coding string that results in appending the cities to listed coordinates via jeff and citipy- thanks!

longitude_group = toluene_clean.groupby(by = 'MONITOR_LONGITUDE')
longitude_list = longitude_group['MONITOR_LONGITUDE'].unique()
longitude_list
# Out:
# MONITOR_LONGITUDE
# -75.244010     [-75.24401]
# -75.125291    [-75.125291]
# -75.097617    [-75.097617]
# -74.742644    [-74.742644]
# -74.676301    [-74.676301]
# -74.453808    [-74.453808]
# -74.441067    [-74.441067]
# -74.429439    [-74.429439]
# -74.422403    [-74.422403]
# -74.208365    [-74.208365]
# -74.199861    [-74.199861]
# -74.192892    [-74.192892]
# -74.176733    [-74.176733]
# -74.168092    [-74.168092]
# -74.160611    [-74.160611]
# -74.143741    [-74.143741]
# -74.126081    [-74.126081]
# -73.966212    [-73.966212]
# Name: MONITOR_LONGITUDE, dtype: object

# %%
# getting coordinate sets

coordinates = []
    
for index, row in toluene_clean.iterrows(): 
    if (row['MONITOR_LATITUDE'], row['MONITOR_LONGITUDE']) not in coordinates:
        coordinates.append((row['MONITOR_LATITUDE'],row['MONITOR_LONGITUDE']))

# %%
# getting cities for coordinate pairs

cities = []
for coordinate_pair in coordinates:
    lat, lon = coordinate_pair
    cities.append(citipy.nearest_city(lat, lon))
cities
# Out:
# [<citipy.citipy.City at 0x1e27b5d6a48>,
#  <citipy.citipy.City at 0x1e27b5e0b08>,
#  <citipy.citipy.City at 0x1e27b5d6a48>,
#  <citipy.citipy.City at 0x1e27b5e0b08>,
#  <citipy.citipy.City at 0x1e27b5e03c8>,
#  <citipy.citipy.City at 0x1e27b5d6e08>,
#  <citipy.citipy.City at 0x1e27b5da888>,
#  <citipy.citipy.City at 0x1e27b5d4248>,
#  <citipy.citipy.City at 0x1e27b5e0788>,
#  <citipy.citipy.City at 0x1e27b5d2488>,
#  <citipy.citipy.City at 0x1e27b5da508>,
#  <citipy.citipy.City at 0x1e27b653d08>,
#  <citipy.citipy.City at 0x1e27b5e2688>,
#  <citipy.citipy.City at 0x1e27b5e2688>,
#  <citipy.citipy.City at 0x1e27b5e2688>,
#  <citipy.citipy.City at 0x1e27b5dad88>,
#  <citipy.citipy.City at 0x1e27b5d4248>,
#  <citipy.citipy.City at 0x1e27b5d85c8>]

# %%
# setting a list to hold the city names, getting city names

city_names = []
for city in cities:
    city_names.append(city.city_name)
city_names
# Out:
# ['elizabeth',
#  'north plainfield',
#  'elizabeth',
#  'north plainfield',
#  'new brunswick',
#  'ewing',
#  'highland park',
#  'camden',
#  'newark',
#  'bayonne',
#  'harrison',
#  'darby',
#  'paterson',
#  'paterson',
#  'paterson',
#  'hopatcong',
#  'camden',
#  'fort lee']

# %%
# display data

city_data = pd.DataFrame({'Coordinates':coordinates,'City Name': city_names})
city_data
# Out:
#                          Coordinates         City Name
# 0             (40.64144, -74.208365)         elizabeth
# 1            (40.601725, -74.441067)  north plainfield
# 2            (40.652053, -74.199861)         elizabeth
# 3            (40.598028, -74.453808)  north plainfield
# 4            (40.462182, -74.429439)     new brunswick
# 5   (40.283091999999996, -74.742644)             ewing
# 6            (40.472825, -74.422403)     highland park
# 7   (39.923041999999995, -75.097617)            camden
# 8            (40.720989, -74.192892)            newark
# 9             (40.67025, -74.126081)           bayonne
# 10           (40.726668, -74.143741)          harrison
# 11             (39.83709, -75.24401)             darby
# 12  (40.915746999999996, -74.176733)          paterson
# 13           (40.927458, -74.160611)          paterson
# 14           (40.918381, -74.168092)          paterson
# 15  (40.787628000000005, -74.676301)         hopatcong
# 16           (39.934446, -75.125291)            camden
# 17  (40.853578999999996, -73.966212)          fort lee

# %%
# test

city_data['Coordinates'][0][0]
# Out:
# 40.64144

# %%
# appending city's to cleaned df

city_index = []
for index, row in toluene_clean.iterrows():
    for cindex, crow in city_data.iterrows():
        if crow['Coordinates'][1] == row['MONITOR_LONGITUDE']:
            city_index.append(crow['City Name'])
            continue
            
toluene_clean['City'] = city_index            
toluene_clean.head()
# Out:
#   PROGRAM  CENSUS_TRACT_POPULATION_2010  MONITOR_LATITUDE  MONITOR_LONGITUDE  \
# 0   SLAMS                          3685          40.64144         -74.208365
# 1   SLAMS                          3685          40.64144         -74.208365
# 2   SLAMS                          3685          40.64144         -74.208365
# 3   SLAMS                          3685          40.64144         -74.208365
# 4   SLAMS                          3685          40.64144         -74.208365
#
#    YEAR  QUARTER SAMPLE_DATE SAMPLE_START_TIME   DATA_SOURCE DURATION_DESC  \
# 0  2016        3   17-Sep-16             18:00  AQS_20171121        1 HOUR
# 1  2016        3   17-Sep-16             05:00  AQS_20171121        1 HOUR
# 2  2016        3   18-Sep-16             09:00  AQS_20171121        1 HOUR
# 3  2016        3   18-Sep-16             08:00  AQS_20171121        1 HOUR
# 4  2016        3   18-Sep-16             07:00  AQS_20171121        1 HOUR
#
#    ...  AQS_UNIT_CODE SAMPLING_FREQUENCY_CODE  SAMPLE_VALUE_STD_FINAL_UG_M3  \
# 0  ...              8                       1                      0.634496
# 1  ...              8                       1                      4.265894
# 2  ...              8                       1                      2.103553
# 3  ...              8                       1                      2.332506
# 4  ...              8                       1                      2.042216
#
#   SAMPLE_VALUE_STD_FINAL_TYPE  MDL_STD_UG_M3     MDL_TYPE  AQS_METHOD_CODE  \
# 0                           L       0.376857  FEDERAL_MDL               92
# 1                           L       0.376857  FEDERAL_MDL               92
# 2                           L       0.376857  FEDERAL_MDL               92
# 3                           L       0.376857  FEDERAL_MDL               92
# 4                           L       0.376857  FEDERAL_MDL               92
#
#   SAMPLE_COLLECTION_DESC     SAMPLE_ANALYSIS_DESC       City
# 0          Tenax/GR/Trap  Thermal Desorber GC/PID  elizabeth
# 1          Tenax/GR/Trap  Thermal Desorber GC/PID  elizabeth
# 2          Tenax/GR/Trap  Thermal Desorber GC/PID  elizabeth
# 3          Tenax/GR/Trap  Thermal Desorber GC/PID  elizabeth
# 4          Tenax/GR/Trap  Thermal Desorber GC/PID  elizabeth
#
# [5 rows x 22 columns]

# %%
# another look after append.  

# it looks like that there are three testing sites with the nearest city being paterson? 
# all the paterson data has been bundled into one site. this might be an issue...
# let's make a note to look closer here

print(f"program descript: {len(toluene_clean.PROGRAM.value_counts())} programs")
print(toluene_clean.PROGRAM.value_counts())
print()
print(f"duration descript:")
print(toluene_clean.DURATION_DESC.value_counts())
print()
print(f"***total locations: lat-{toluene_clean.MONITOR_LATITUDE.value_counts().count()} / lon-{toluene_clean.MONITOR_LONGITUDE.value_counts().count()}")
print(f"***total cities:  {len(toluene_clean.City.value_counts())}")
print()
print(f"city list: ")
print(toluene_clean.City.value_counts())
# Out:
# program descript: 6 programs
# PAMS                            92910
# SLAMS                           27433
# UATMP                            3116
# OTHER                             255
# SPECIAL PURPOSE                    95
# SCHOOL AIR TOXICS MONITORING       51
# Name: PROGRAM, dtype: int64
#
# duration descript:
# 1 HOUR      119498
# 24 HOURS      4186
# 3 HOURS        176
# Name: DURATION_DESC, dtype: int64
#
# ***total locations: lat-18 / lon-18
# ***total cities:  13
#
# city list:
# new brunswick       38371
# ewing               31304
# camden              30234
# newark               6313
# elizabeth            6249
# bayonne              6116
# fort lee             2973
# hopatcong             962
# highland park         911
# paterson              187
# harrison              125
# north plainfield       88
# darby                  27
# Name: City, dtype: int64

# %%
# extracting hourly test data
toluene_hourly = toluene_clean[toluene_clean['DURATION_DESC'] == '1 HOUR']

# %%
toluene_hourly.head()
# Out:
#   PROGRAM  CENSUS_TRACT_POPULATION_2010  MONITOR_LATITUDE  MONITOR_LONGITUDE  \
# 0   SLAMS                          3685          40.64144         -74.208365
# 1   SLAMS                          3685          40.64144         -74.208365
# 2   SLAMS                          3685          40.64144         -74.208365
# 3   SLAMS                          3685          40.64144         -74.208365
# 4   SLAMS                          3685          40.64144         -74.208365
#
#    YEAR  QUARTER SAMPLE_DATE SAMPLE_START_TIME   DATA_SOURCE DURATION_DESC  \
# 0  2016        3   17-Sep-16             18:00  AQS_20171121        1 HOUR
# 1  2016        3   17-Sep-16             05:00  AQS_20171121        1 HOUR
# 2  2016        3   18-Sep-16             09:00  AQS_20171121        1 HOUR
# 3  2016        3   18-Sep-16             08:00  AQS_20171121        1 HOUR
# 4  2016        3   18-Sep-16             07:00  AQS_20171121        1 HOUR
#
#    ...  AQS_UNIT_CODE SAMPLING_FREQUENCY_CODE  SAMPLE_VALUE_STD_FINAL_UG_M3  \
# 0  ...              8                       1                      0.634496
# 1  ...              8                       1                      4.265894
# 2  ...              8                       1                      2.103553
# 3  ...              8                       1                      2.332506
# 4  ...              8                       1                      2.042216
#
#   SAMPLE_VALUE_STD_FINAL_TYPE  MDL_STD_UG_M3     MDL_TYPE  AQS_METHOD_CODE  \
# 0                           L       0.376857  FEDERAL_MDL               92
# 1                           L       0.376857  FEDERAL_MDL               92
# 2                           L       0.376857  FEDERAL_MDL               92
# 3                           L       0.376857  FEDERAL_MDL               92
# 4                           L       0.376857  FEDERAL_MDL               92
#
#   SAMPLE_COLLECTION_DESC     SAMPLE_ANALYSIS_DESC       City
# 0          Tenax/GR/Trap  Thermal Desorber GC/PID  elizabeth
# 1          Tenax/GR/Trap  Thermal Desorber GC/PID  elizabeth
# 2          Tenax/GR/Trap  Thermal Desorber GC/PID  elizabeth
# 3          Tenax/GR/Trap  Thermal Desorber GC/PID  elizabeth
# 4          Tenax/GR/Trap  Thermal Desorber GC/PID  elizabeth
#
# [5 rows x 22 columns]

# %%
# extracting daily test data

toluene_daily = toluene_clean[toluene_clean['DURATION_DESC'] == '24 HOURS']
toluene_daily.head()
# Out:
#      PROGRAM  CENSUS_TRACT_POPULATION_2010  MONITOR_LATITUDE  \
# 1859   UATMP                          3685          40.64144
# 1860   UATMP                          3685          40.64144
# 1861   UATMP                          3685          40.64144
# 1862   UATMP                          3685          40.64144
# 1863   UATMP                          3685          40.64144
#
#       MONITOR_LONGITUDE  YEAR  QUARTER SAMPLE_DATE SAMPLE_START_TIME  \
# 1859         -74.208365  2008        4   09-Oct-08             00:00
# 1860         -74.208365  2008        3   20-Jul-08             00:00
# 1861         -74.208365  2008        4   26-Dec-08             00:00
# 1862         -74.208365  2008        4   20-Dec-08             00:00
# 1863         -74.208365  2008        4   14-Dec-08             00:00
#
#        DATA_SOURCE DURATION_DESC  ...  AQS_UNIT_CODE SAMPLING_FREQUENCY_CODE  \
# 1859  AQS_20171121      24 HOURS  ...              8                       6
# 1860  AQS_20171121      24 HOURS  ...              8                       6
# 1861  AQS_20171121      24 HOURS  ...              8                       6
# 1862  AQS_20171121      24 HOURS  ...              8                       6
# 1863  AQS_20171121      24 HOURS  ...              8                       6
#
#       SAMPLE_VALUE_STD_FINAL_UG_M3 SAMPLE_VALUE_STD_FINAL_TYPE  MDL_STD_UG_M3  \
# 1859                      3.354024                           L       0.086677
# 1860                      1.680781                           L       0.086677
# 1861                           NaN                           L       0.086677
# 1862                      1.820218                           L       0.086677
# 1863                      2.204612                           L       0.086677
#
#             MDL_TYPE  AQS_METHOD_CODE        SAMPLE_COLLECTION_DESC  \
# 1859  ENTITY_ENTERED              101  CANISTER SUBAMBIENT PRESSURE
# 1860  ENTITY_ENTERED              101  CANISTER SUBAMBIENT PRESSURE
# 1861  MIN_OF_ALT_MDL              101  CANISTER SUBAMBIENT PRESSURE
# 1862  ENTITY_ENTERED              101  CANISTER SUBAMBIENT PRESSURE
# 1863  ENTITY_ENTERED              101  CANISTER SUBAMBIENT PRESSURE
#
#       SAMPLE_ANALYSIS_DESC       City
# 1859     MULTI DETECTOR GC  elizabeth
# 1860     MULTI DETECTOR GC  elizabeth
# 1861     MULTI DETECTOR GC  elizabeth
# 1862     MULTI DETECTOR GC  elizabeth
# 1863     MULTI DETECTOR GC  elizabeth
#
# [5 rows x 22 columns]

# %%
# extracting three hour duration test data

toluene_three = toluene_clean[toluene_clean['DURATION_DESC'] == '3 HOURS']
toluene_three.head()
# Out:
#      PROGRAM  CENSUS_TRACT_POPULATION_2010  MONITOR_LATITUDE  \
# 2439   OTHER                          6329         40.601725
# 2440   OTHER                          6329         40.601725
# 2441   OTHER                          6329         40.601725
# 2442   OTHER                          6329         40.601725
# 2443   OTHER                          6329         40.601725
#
#       MONITOR_LONGITUDE  YEAR  QUARTER SAMPLE_DATE SAMPLE_START_TIME  \
# 2439         -74.441067  1993        3   02-Aug-93             05:00
# 2440         -74.441067  1993        3   23-Jul-93             06:00
# 2441         -74.441067  1996        3   12-Jul-96             06:00
# 2442         -74.441067  1996        2   28-Jun-96             06:00
# 2443         -74.441067  1994        4   13-Oct-94             05:00
#
#        DATA_SOURCE DURATION_DESC  ...  AQS_UNIT_CODE SAMPLING_FREQUENCY_CODE  \
# 2439  AQS_20171121       3 HOURS  ...             78                       9
# 2440  AQS_20171121       3 HOURS  ...              8                       9
# 2441  AQS_20171121       3 HOURS  ...             78                       9
# 2442  AQS_20171121       3 HOURS  ...             78                       9
# 2443  AQS_20171121       3 HOURS  ...             78                       6
#
#       SAMPLE_VALUE_STD_FINAL_UG_M3 SAMPLE_VALUE_STD_FINAL_TYPE  MDL_STD_UG_M3  \
# 2439                     23.241290                           L       0.005384
# 2440                      1.695855                           L       0.376857
# 2441                     14.858921                           L       0.053837
# 2442                     16.619380                           L       0.053837
# 2443                     59.920213                           L       0.005384
#
#          MDL_TYPE  AQS_METHOD_CODE        SAMPLE_COLLECTION_DESC  \
# 2439  FEDERAL_MDL              123       6L PRESSURIZED CANISTER
# 2440  FEDERAL_MDL              101  CANISTER SUBAMBIENT PRESSURE
# 2441  FEDERAL_MDL              126       SS CANISTER PRESSURIZED
# 2442  FEDERAL_MDL              126       SS CANISTER PRESSURIZED
# 2443  FEDERAL_MDL              123       6L PRESSURIZED CANISTER
#
#                    SAMPLE_ANALYSIS_DESC              City
# 2439                    DUAL FID - PAMS  north plainfield
# 2440                  MULTI DETECTOR GC  north plainfield
# 2441  CRYOGENIC PRECONCENTRATION GC/FID  north plainfield
# 2442  CRYOGENIC PRECONCENTRATION GC/FID  north plainfield
# 2443                    DUAL FID - PAMS  north plainfield
#
# [5 rows x 22 columns]

# %%
# grouping overall test result means by year

yearly = toluene_clean.groupby(by='YEAR')
year_group = yearly['SAMPLE_VALUE_STD_FINAL_UG_M3'].mean()
year_group_db = pd.DataFrame(year_group)
year_group_db
# Out:
#       SAMPLE_VALUE_STD_FINAL_UG_M3
# YEAR
# 1990                     10.865009
# 1991                     17.910314
# 1992                     17.469820
# 1993                     12.581520
# 1994                     13.681692
# 1995                      2.379641
# 1996                      4.041037
# 1997                      3.616655
# 1998                      3.285326
# 1999                      2.749267
# 2000                      2.643130
# 2001                      2.908448
# 2002                      2.148268
# 2003                      2.231783
# 2004                      5.983963
# 2005                      2.261997
# 2006                      1.470116
# 2007                      1.391729
# 2008                      1.598624
# 2009                      1.660722
# 2010                      0.929808
# 2011                      0.947460
# 2012                      1.041875
# 2013                      0.831404
# 2014                      0.678599
# 2015                      1.171501
# 2016                      2.307031

# %%
# plotting by year.  
# this shows that there was some change in regulation between 1994 and 1995.

ax = year_group_db.plot.bar(rot=0, figsize=(10,5))
plt.xlabel('Years', size=10)
plt.ylabel('Value Mean', size=10)
plt.title('Standardized Mean by Year', size=12)
plt.grid(alpha=0.4)
plt.xticks(rotation=50)
plt.show()

# %%
# grouping by location

latitude = toluene_clean.groupby(by='MONITOR_LATITUDE')
latitude_group = latitude['SAMPLE_VALUE_STD_FINAL_UG_M3'].mean()
latitude_group_db = pd.DataFrame(latitude_group)
latitude_group_db
# Out:
#                   SAMPLE_VALUE_STD_FINAL_UG_M3
# MONITOR_LATITUDE
# 39.837090                             2.372627
# 39.923042                             2.753091
# 39.934446                             2.810341
# 40.283092                             1.406715
# 40.462182                             3.098485
# 40.472825                             2.979197
# 40.598028                            18.624098
# 40.601725                            18.772494
# 40.641440                             2.973165
# 40.652053                             2.108342
# 40.670250                             2.686103
# 40.720989                             1.670011
# 40.726668                            16.516229
# 40.787628                             1.824185
# 40.853579                             1.720701
# 40.915747                             1.152255
# 40.918381                             4.128747
# 40.927458                             0.923239

# %%
# getting result means by location

ax = latitude_group_db.plot.bar(rot=0, figsize=(15,7))
plt.xlabel('Lats', size=8)
plt.ylabel('Value Mean', size=10)
plt.title('Standardized Mean by Year', size=12)
plt.grid(alpha=0.4)
plt.xticks(rotation=90)
# plt.show()

# %%
# next scatter plots look at the sample values across all testing durations
# below is overall

toluene_clean.plot.scatter(x='YEAR', y='SAMPLE_VALUE_STD_FINAL_UG_M3')

# %%
# sample values for hourly tests

toluene_hourly.plot.scatter(x='YEAR', y='SAMPLE_VALUE_STD_FINAL_UG_M3')

# %%
# sample values for daily tests

toluene_daily.plot.scatter(x='YEAR', y='SAMPLE_VALUE_STD_FINAL_UG_M3')

# %%
# sample values for three our duration tests

toluene_three.plot.scatter(x='YEAR', y='SAMPLE_VALUE_STD_FINAL_UG_M3')

# %%
# breaking out the following 6 programs into their own df's for future analysis

print(toluene_clean.PROGRAM.value_counts())
# Out:
# PAMS                            92910
# SLAMS                           27433
# UATMP                            3116
# OTHER                             255
# SPECIAL PURPOSE                    95
# SCHOOL AIR TOXICS MONITORING       51
# Name: PROGRAM, dtype: int64

# %%
# 1
pams_toluene_df = toluene_clean.loc[toluene_clean["PROGRAM"] =="PAMS"]
pams_toluene_df.head()
# Out:
#      PROGRAM  CENSUS_TRACT_POPULATION_2010  MONITOR_LATITUDE  \
# 3718    PAMS                          5231         40.462182
# 3719    PAMS                          5231         40.462182
# 3720    PAMS                          5231         40.462182
# 3721    PAMS                          5231         40.462182
# 3722    PAMS                          5231         40.462182
#
#       MONITOR_LONGITUDE  YEAR  QUARTER SAMPLE_DATE SAMPLE_START_TIME  \
# 3718         -74.429439  1997        2   13-Jun-97             22:00
# 3719         -74.429439  1997        2   15-Jun-97             06:00
# 3720         -74.429439  1997        2   14-Jun-97             07:00
# 3721         -74.429439  1997        2   14-Jun-97             06:00
# 3722         -74.429439  1997        2   14-Jun-97             05:00
#
#        DATA_SOURCE DURATION_DESC  ...  AQS_UNIT_CODE SAMPLING_FREQUENCY_CODE  \
# 3718  AQS_20171121        1 HOUR  ...             78                       1
# 3719  AQS_20171121        1 HOUR  ...             78                       1
# 3720  AQS_20171121        1 HOUR  ...             78                       1
# 3721  AQS_20171121        1 HOUR  ...             78                       1
# 3722  AQS_20171121        1 HOUR  ...             78                       1
#
#       SAMPLE_VALUE_STD_FINAL_UG_M3 SAMPLE_VALUE_STD_FINAL_TYPE  MDL_STD_UG_M3  \
# 3718                      3.014853                           L       0.005384
# 3719                      1.453590                           L       0.005384
# 3720                      1.022897                           L       0.005384
# 3721                      2.368813                           L       0.005384
# 3722                     36.285915                           L       0.005384
#
#          MDL_TYPE  AQS_METHOD_CODE SAMPLE_COLLECTION_DESC  \
# 3718  FEDERAL_MDL              128  PRECONCENTRATION TRAP
# 3719  FEDERAL_MDL              128  PRECONCENTRATION TRAP
# 3720  FEDERAL_MDL              128  PRECONCENTRATION TRAP
# 3721  FEDERAL_MDL              128  PRECONCENTRATION TRAP
# 3722  FEDERAL_MDL              128  PRECONCENTRATION TRAP
#
#                      SAMPLE_ANALYSIS_DESC           City
# 3718  PE 8700;AUTO GC;SUBAMBIENT-DUAL FID  new brunswick
# 3719  PE 8700;AUTO GC;SUBAMBIENT-DUAL FID  new brunswick
# 3720  PE 8700;AUTO GC;SUBAMBIENT-DUAL FID  new brunswick
# 3721  PE 8700;AUTO GC;SUBAMBIENT-DUAL FID  new brunswick
# 3722  PE 8700;AUTO GC;SUBAMBIENT-DUAL FID  new brunswick
#
# [5 rows x 22 columns]

# %%
# beginning testing for geo-mapping overlay

pams = pams_toluene_df.groupby(['YEAR'])
pams_maxes = pd.DataFrame(pams['SAMPLE_VALUE_STD_FINAL_UG_M3'].max())
pams_maxes.head()
# Out:
#       SAMPLE_VALUE_STD_FINAL_UG_M3
# YEAR
# 1990                     20.387947
# 1991                    196.945304
# 1992                     27.171367
# 1993                     30.676134
# 1994                     35.876756

# %%
pams_lat_array = pams_toluene_df['MONITOR_LATITUDE'].unique()
pams_lat_array
# Out:
# array([40.462182, 40.283092, 39.923042])

# %%
pams_lng_array = pams_toluene_df['MONITOR_LONGITUDE'].unique()
pams_lng_array
# Out:
# array([-74.429439, -74.742644, -75.097617])

# %%
pams_coords = [
    (40.462182, -74.429439),
    (40.283092, -74.742644),
    (39.923042, -75.097617)
]

# %%
figure_layout = {
    'width': '800px',
    'height': '300px',
    'border': '1px solid black',
    'padding': '1px',
    'margin': '0 auto 0 auto'
}
fig = gmaps.figure(layout=figure_layout)

# %%
markers = gmaps.marker_layer(pams_coords)
fig.add_layer(markers)
fig
# Out:
# Figure(layout=FigureLayout(border='1px solid black', height='300px', margin='0 auto 0 auto', padding='1px', wi…

# %%
locations = pams_toluene_df[['MONITOR_LATITUDE', 'MONITOR_LONGITUDE']]
weights = pams_toluene_df['SAMPLE_VALUE_STD_FINAL_UG_M3']
fig = gmaps.figure()
fig.add_layer(gmaps.heatmap_layer(locations, weights=weights))
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# 2 

slams_toluene_df = toluene_clean.loc[toluene_clean["PROGRAM"] =="SLAMS"]
slams_toluene_df.head()
# Out:
#   PROGRAM  CENSUS_TRACT_POPULATION_2010  MONITOR_LATITUDE  MONITOR_LONGITUDE  \
# 0   SLAMS                          3685          40.64144         -74.208365
# 1   SLAMS                          3685          40.64144         -74.208365
# 2   SLAMS                          3685          40.64144         -74.208365
# 3   SLAMS                          3685          40.64144         -74.208365
# 4   SLAMS                          3685          40.64144         -74.208365
#
#    YEAR  QUARTER SAMPLE_DATE SAMPLE_START_TIME   DATA_SOURCE DURATION_DESC  \
# 0  2016        3   17-Sep-16             18:00  AQS_20171121        1 HOUR
# 1  2016        3   17-Sep-16             05:00  AQS_20171121        1 HOUR
# 2  2016        3   18-Sep-16             09:00  AQS_20171121        1 HOUR
# 3  2016        3   18-Sep-16             08:00  AQS_20171121        1 HOUR
# 4  2016        3   18-Sep-16             07:00  AQS_20171121        1 HOUR
#
#    ...  AQS_UNIT_CODE SAMPLING_FREQUENCY_CODE  SAMPLE_VALUE_STD_FINAL_UG_M3  \
# 0  ...              8                       1                      0.634496
# 1  ...              8                       1                      4.265894
# 2  ...              8                       1                      2.103553
# 3  ...              8                       1                      2.332506
# 4  ...              8                       1                      2.042216
#
#   SAMPLE_VALUE_STD_FINAL_TYPE  MDL_STD_UG_M3     MDL_TYPE  AQS_METHOD_CODE  \
# 0                           L       0.376857  FEDERAL_MDL               92
# 1                           L       0.376857  FEDERAL_MDL               92
# 2                           L       0.376857  FEDERAL_MDL               92
# 3                           L       0.376857  FEDERAL_MDL               92
# 4                           L       0.376857  FEDERAL_MDL               92
#
#   SAMPLE_COLLECTION_DESC     SAMPLE_ANALYSIS_DESC       City
# 0          Tenax/GR/Trap  Thermal Desorber GC/PID  elizabeth
# 1          Tenax/GR/Trap  Thermal Desorber GC/PID  elizabeth
# 2          Tenax/GR/Trap  Thermal Desorber GC/PID  elizabeth
# 3          Tenax/GR/Trap  Thermal Desorber GC/PID  elizabeth
# 4          Tenax/GR/Trap  Thermal Desorber GC/PID  elizabeth
#
# [5 rows x 22 columns]

# %%
# 3 

uatmp_toluene_df = toluene_clean.loc[toluene_clean["PROGRAM"] =="UATMP"]
uatmp_toluene_df.head()
# Out:
#      PROGRAM  CENSUS_TRACT_POPULATION_2010  MONITOR_LATITUDE  \
# 1859   UATMP                          3685          40.64144
# 1860   UATMP                          3685          40.64144
# 1861   UATMP                          3685          40.64144
# 1862   UATMP                          3685          40.64144
# 1863   UATMP                          3685          40.64144
#
#       MONITOR_LONGITUDE  YEAR  QUARTER SAMPLE_DATE SAMPLE_START_TIME  \
# 1859         -74.208365  2008        4   09-Oct-08             00:00
# 1860         -74.208365  2008        3   20-Jul-08             00:00
# 1861         -74.208365  2008        4   26-Dec-08             00:00
# 1862         -74.208365  2008        4   20-Dec-08             00:00
# 1863         -74.208365  2008        4   14-Dec-08             00:00
#
#        DATA_SOURCE DURATION_DESC  ...  AQS_UNIT_CODE SAMPLING_FREQUENCY_CODE  \
# 1859  AQS_20171121      24 HOURS  ...              8                       6
# 1860  AQS_20171121      24 HOURS  ...              8                       6
# 1861  AQS_20171121      24 HOURS  ...              8                       6
# 1862  AQS_20171121      24 HOURS  ...              8                       6
# 1863  AQS_20171121      24 HOURS  ...              8                       6
#
#       SAMPLE_VALUE_STD_FINAL_UG_M3 SAMPLE_VALUE_STD_FINAL_TYPE  MDL_STD_UG_M3  \
# 1859                      3.354024                           L       0.086677
# 1860                      1.680781                           L       0.086677
# 1861                           NaN                           L       0.086677
# 1862                      1.820218                           L       0.086677
# 1863                      2.204612                           L       0.086677
#
#             MDL_TYPE  AQS_METHOD_CODE        SAMPLE_COLLECTION_DESC  \
# 1859  ENTITY_ENTERED              101  CANISTER SUBAMBIENT PRESSURE
# 1860  ENTITY_ENTERED              101  CANISTER SUBAMBIENT PRESSURE
# 1861  MIN_OF_ALT_MDL              101  CANISTER SUBAMBIENT PRESSURE
# 1862  ENTITY_ENTERED              101  CANISTER SUBAMBIENT PRESSURE
# 1863  ENTITY_ENTERED              101  CANISTER SUBAMBIENT PRESSURE
#
#       SAMPLE_ANALYSIS_DESC       City
# 1859     MULTI DETECTOR GC  elizabeth
# 1860     MULTI DETECTOR GC  elizabeth
# 1861     MULTI DETECTOR GC  elizabeth
# 1862     MULTI DETECTOR GC  elizabeth
# 1863     MULTI DETECTOR GC  elizabeth
#
# [5 rows x 22 columns]

# %%
# 4

other_toluene_df = toluene_clean.loc[toluene_clean["PROGRAM"] =="OTHER"]
other_toluene_df.head()
# Out:
#      PROGRAM  CENSUS_TRACT_POPULATION_2010  MONITOR_LATITUDE  \
# 2439   OTHER                          6329         40.601725
# 2440   OTHER                          6329         40.601725
# 2441   OTHER                          6329         40.601725
# 2442   OTHER                          6329         40.601725
# 2443   OTHER                          6329         40.601725
#
#       MONITOR_LONGITUDE  YEAR  QUARTER SAMPLE_DATE SAMPLE_START_TIME  \
# 2439         -74.441067  1993        3   02-Aug-93             05:00
# 2440         -74.441067  1993        3   23-Jul-93             06:00
# 2441         -74.441067  1996        3   12-Jul-96             06:00
# 2442         -74.441067  1996        2   28-Jun-96             06:00
# 2443         -74.441067  1994        4   13-Oct-94             05:00
#
#        DATA_SOURCE DURATION_DESC  ...  AQS_UNIT_CODE SAMPLING_FREQUENCY_CODE  \
# 2439  AQS_20171121       3 HOURS  ...             78                       9
# 2440  AQS_20171121       3 HOURS  ...              8                       9
# 2441  AQS_20171121       3 HOURS  ...             78                       9
# 2442  AQS_20171121       3 HOURS  ...             78                       9
# 2443  AQS_20171121       3 HOURS  ...             78                       6
#
#       SAMPLE_VALUE_STD_FINAL_UG_M3 SAMPLE_VALUE_STD_FINAL_TYPE  MDL_STD_UG_M3  \
# 2439                     23.241290                           L       0.005384
# 2440                      1.695855                           L       0.376857
# 2441                     14.858921                           L       0.053837
# 2442                     16.619380                           L       0.053837
# 2443                     59.920213                           L       0.005384
#
#          MDL_TYPE  AQS_METHOD_CODE        SAMPLE_COLLECTION_DESC  \
# 2439  FEDERAL_MDL              123       6L PRESSURIZED CANISTER
# 2440  FEDERAL_MDL              101  CANISTER SUBAMBIENT PRESSURE
# 2441  FEDERAL_MDL              126       SS CANISTER PRESSURIZED
# 2442  FEDERAL_MDL              126       SS CANISTER PRESSURIZED
# 2443  FEDERAL_MDL              123       6L PRESSURIZED CANISTER
#
#                    SAMPLE_ANALYSIS_DESC              City
# 2439                    DUAL FID - PAMS  north plainfield
# 2440                  MULTI DETECTOR GC  north plainfield
# 2441  CRYOGENIC PRECONCENTRATION GC/FID  north plainfield
# 2442  CRYOGENIC PRECONCENTRATION GC/FID  north plainfield
# 2443                    DUAL FID - PAMS  north plainfield
#
# [5 rows x 22 columns]

# %%
# 5

special_purpose_toluene_df = toluene_clean.loc[toluene_clean["PROGRAM"] =="SPECIAL PURPOSE"]
special_purpose_toluene_df.head()
# Out:
#                PROGRAM  CENSUS_TRACT_POPULATION_2010  MONITOR_LATITUDE  \
# 75563  SPECIAL PURPOSE                          3850         40.915747
# 75565  SPECIAL PURPOSE                          3850         40.915747
# 75566  SPECIAL PURPOSE                          3850         40.915747
# 75567  SPECIAL PURPOSE                          3850         40.915747
# 75568  SPECIAL PURPOSE                          3850         40.915747
#
#        MONITOR_LONGITUDE  YEAR  QUARTER SAMPLE_DATE SAMPLE_START_TIME  \
# 75563         -74.176733  2006        4   14-Oct-06             00:00
# 75565         -74.176733  2006        4   07-Dec-06             00:00
# 75566         -74.176733  2006        4   01-Dec-06             00:00
# 75567         -74.176733  2006        4   19-Nov-06             00:00
# 75568         -74.176733  2006        4   13-Nov-06             00:00
#
#         DATA_SOURCE DURATION_DESC  ...  AQS_UNIT_CODE SAMPLING_FREQUENCY_CODE  \
# 75563  AQS_20171121      24 HOURS  ...             78                       6
# 75565  AQS_20171121      24 HOURS  ...             78                       6
# 75566  AQS_20171121      24 HOURS  ...             78                       6
# 75567  AQS_20171121      24 HOURS  ...             78                       6
# 75568  AQS_20171121      24 HOURS  ...             78                       6
#
#        SAMPLE_VALUE_STD_FINAL_UG_M3 SAMPLE_VALUE_STD_FINAL_TYPE  \
# 75563                      0.592203                           L
# 75565                      0.301485                           L
# 75566                      0.641195                           L
# 75567                      0.279951                           L
# 75568                      0.829623                           L
#
#        MDL_STD_UG_M3     MDL_TYPE  AQS_METHOD_CODE  \
# 75563       0.053837  FEDERAL_MDL              101
# 75565       0.053837  FEDERAL_MDL              101
# 75566       0.053837  FEDERAL_MDL              101
# 75567       0.053837  FEDERAL_MDL              101
# 75568       0.053837  FEDERAL_MDL              101
#
#              SAMPLE_COLLECTION_DESC  SAMPLE_ANALYSIS_DESC      City
# 75563  CANISTER SUBAMBIENT PRESSURE     MULTI DETECTOR GC  paterson
# 75565  CANISTER SUBAMBIENT PRESSURE     MULTI DETECTOR GC  paterson
# 75566  CANISTER SUBAMBIENT PRESSURE     MULTI DETECTOR GC  paterson
# 75567  CANISTER SUBAMBIENT PRESSURE     MULTI DETECTOR GC  paterson
# 75568  CANISTER SUBAMBIENT PRESSURE     MULTI DETECTOR GC  paterson
#
# [5 rows x 22 columns]

# %%
# 6

school_toluene_df = toluene_clean.loc[toluene_clean["PROGRAM"] =="SCHOOL AIR TOXICS MONITORING"]
school_toluene_df.head()
# Out:
#                            PROGRAM  CENSUS_TRACT_POPULATION_2010  \
# 2468  SCHOOL AIR TOXICS MONITORING                          6072
# 2469  SCHOOL AIR TOXICS MONITORING                          6072
# 2470  SCHOOL AIR TOXICS MONITORING                          6072
# 2471  SCHOOL AIR TOXICS MONITORING                          6072
# 2472  SCHOOL AIR TOXICS MONITORING                          6072
#
#       MONITOR_LATITUDE  MONITOR_LONGITUDE  YEAR  QUARTER SAMPLE_DATE  \
# 2468         40.652053         -74.199861  2009        4   10-Oct-09
# 2469         40.652053         -74.199861  2010        1   19-Jan-10
# 2470         40.652053         -74.199861  2010        1   13-Jan-10
# 2471         40.652053         -74.199861  2009        4   22-Dec-09
# 2472         40.652053         -74.199861  2009        4   15-Dec-09
#
#      SAMPLE_START_TIME   DATA_SOURCE DURATION_DESC  ...  AQS_UNIT_CODE  \
# 2468             00:00  AQS_20171121      24 HOURS  ...              8
# 2469             09:19  AQS_20171121      24 HOURS  ...              8
# 2470             10:11  AQS_20171121      24 HOURS  ...              8
# 2471             10:22  AQS_20171121      24 HOURS  ...              8
# 2472             12:00  AQS_20171121      24 HOURS  ...              8
#
#      SAMPLING_FREQUENCY_CODE  SAMPLE_VALUE_STD_FINAL_UG_M3  \
# 2468                       6                           NaN
# 2469                       9                      3.919310
# 2470                       9                      2.148083
# 2471                       6                      0.535136
# 2472                       6                      0.414542
#
#      SAMPLE_VALUE_STD_FINAL_TYPE  MDL_STD_UG_M3        MDL_TYPE  \
# 2468                           L       0.030149  MIN_OF_ALT_MDL
# 2469                           L       0.030149  ENTITY_ENTERED
# 2470                           L       0.030149  ENTITY_ENTERED
# 2471                           L       0.030149  ENTITY_ENTERED
# 2472                           L       0.030149  ENTITY_ENTERED
#
#       AQS_METHOD_CODE        SAMPLE_COLLECTION_DESC  SAMPLE_ANALYSIS_DESC  \
# 2468              101  CANISTER SUBAMBIENT PRESSURE     MULTI DETECTOR GC
# 2469              101  CANISTER SUBAMBIENT PRESSURE     MULTI DETECTOR GC
# 2470              101  CANISTER SUBAMBIENT PRESSURE     MULTI DETECTOR GC
# 2471              101  CANISTER SUBAMBIENT PRESSURE     MULTI DETECTOR GC
# 2472              101  CANISTER SUBAMBIENT PRESSURE     MULTI DETECTOR GC
#
#            City
# 2468  elizabeth
# 2469  elizabeth
# 2470  elizabeth
# 2471  elizabeth
# 2472  elizabeth
#
# [5 rows x 22 columns]

# %%
school_lat_array = school_toluene_df['MONITOR_LATITUDE'].unique()
school_lat_array
# Out:
# array([40.652053, 39.83709 ])

# %%
school_lng_array = school_toluene_df['MONITOR_LONGITUDE'].unique()
school_lng_array
# Out:
# array([-74.199861, -75.24401 ])

# %%
school_coords = [
    (40.652053, -74.199861),
    (39.83709, -75.24401)
]

# %%
figure_layout = {
    'width': '800px',
    'height': '300px',
    'border': '1px solid black',
    'padding': '1px',
    'margin': '0 auto 0 auto'
}
fig = gmaps.figure(layout=figure_layout)

# %%
markers = gmaps.marker_layer(school_coords)
fig.add_layer(markers)
fig
# Out:
# Figure(layout=FigureLayout(border='1px solid black', height='300px', margin='0 auto 0 auto', padding='1px', wi…

# %%
locations = school_toluene_df[['MONITOR_LATITUDE', 'MONITOR_LONGITUDE']]
weights = school_toluene_df['SAMPLE_VALUE_STD_FINAL_UG_M3']
fig = gmaps.figure()
fig.add_layer(gmaps.heatmap_layer(locations, weights=weights))
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# looking at how much data per city

print(toluene_clean.City.value_counts())
# Out:
# new brunswick       38371
# ewing               31304
# camden              30234
# newark               6313
# elizabeth            6249
# bayonne              6116
# fort lee             2973
# hopatcong             962
# highland park         911
# paterson              187
# harrison              125
# north plainfield       88
# darby                  27
# Name: City, dtype: int64

# %%
# getting the overall means per city for entire data set

city_groupby = toluene_clean.groupby(by='City')
city_groupby = city_groupby['SAMPLE_VALUE_STD_FINAL_UG_M3'].mean()
city_groupby_db = pd.DataFrame(city_groupby)
city_groupby_db
# Out:
#                   SAMPLE_VALUE_STD_FINAL_UG_M3
# City
# bayonne                               2.686103
# camden                                2.765113
# darby                                 2.372627
# elizabeth                             2.971632
# ewing                                 1.406715
# fort lee                              1.720701
# harrison                             16.516229
# highland park                         2.979197
# hopatcong                             1.824185
# new brunswick                         3.098485
# newark                                1.670011
# north plainfield                     18.726963
# paterson                              2.463563

# %%
## USE ##



# a look at the lat graph approach but organized by city. 
# pretty different. see paterson.

ax = city_groupby_db.plot.bar(rot=0, figsize=(15,7))
plt.xlabel('City', size=8)
plt.ylabel('Value Mean', size=10)
plt.title('Standardized Mean Across all Years by City', size=12)
plt.grid(alpha=0.4)
plt.xticks(rotation=90)
plt.show()

# %%
# multi level index df (groupby) to get yearly means by city. 

yearcity_groupby = toluene_clean.groupby(['City', 'YEAR'])['SAMPLE_VALUE_STD_FINAL_UG_M3']
mean_by_year = yearcity_groupby.mean()
mean_by_year_df = pd.DataFrame(mean_by_year)
mean_by_year_df.head()
# Out:
#               SAMPLE_VALUE_STD_FINAL_UG_M3
# City    YEAR
# bayonne 2016                      2.686103
# camden  1990                      8.306651
#         1991                     20.145682
#         1992                      9.176460
#         1993                      7.367548

# %%
# multi level index df (groupby) to get yearly means by city. 

yearcity_groupby = toluene_clean.groupby(['City', 'YEAR'])['SAMPLE_VALUE_STD_FINAL_UG_M3']
max_by_year = yearcity_groupby.max()
max_by_year_df = pd.DataFrame(max_by_year)
max_by_year_df.head()
# Out:
#               SAMPLE_VALUE_STD_FINAL_UG_M3
# City    YEAR
# bayonne 2016                     38.578051
# camden  1990                     20.387947
#         1991                    196.945304
#         1992                     27.171367
#         1993                     30.676134

# %%
clean_max = max_by_year_df.reset_index().pivot('YEAR','City','SAMPLE_VALUE_STD_FINAL_UG_M3')
clean_max
# Out:
# City    bayonne      camden     darby  elizabeth       ewing  fort lee  \
# YEAR
# 1990        NaN   20.387947       NaN        NaN         NaN       NaN
# 1991        NaN  196.945304       NaN        NaN         NaN       NaN
# 1992        NaN   27.171367       NaN        NaN         NaN       NaN
# 1993        NaN   30.676134       NaN        NaN         NaN       NaN
# 1994        NaN   35.876756       NaN        NaN         NaN       NaN
# 1995        NaN   35.198414       NaN        NaN   34.401632       NaN
# 1996        NaN   20.425632       NaN        NaN   37.685669       NaN
# 1997        NaN   37.793342       NaN        NaN   21.157811       NaN
# 1998        NaN   24.226501       NaN        NaN   21.265484       NaN
# 1999        NaN   36.178242       NaN        NaN   23.311278       NaN
# 2000        NaN   31.332942       NaN  33.238760   20.511771       NaN
# 2001        NaN   42.207949       NaN  13.868326    8.667704       NaN
# 2002        NaN   52.060059       NaN  20.387947   18.519814       NaN
# 2003        NaN   20.242588       NaN  14.245183  127.592906       NaN
# 2004        NaN   72.302647       NaN  13.416098   16.850877       NaN
# 2005        NaN   19.004344       NaN  13.981383    6.675747       NaN
# 2006        NaN   20.027241       NaN  12.285528    5.975870       NaN
# 2007        NaN   16.904714       NaN  12.172471    9.744437       NaN
# 2008        NaN   85.169611       NaN  15.564181    4.629954       NaN
# 2009        NaN         NaN  3.956995  33.050331    6.083544       NaN
# 2010        NaN         NaN  4.032367   7.951676   12.490107       NaN
# 2011        NaN         NaN       NaN  42.584805         NaN       NaN
# 2012        NaN         NaN       NaN   7.838619         NaN       NaN
# 2013        NaN   13.868326       NaN   6.481935         NaN       NaN
# 2014        NaN   11.644872       NaN   6.708049         NaN       NaN
# 2015        NaN   26.266911       NaN   3.919310         NaN       NaN
# 2016  38.578051   90.440798       NaN  48.199720         NaN  51.57135
#
# City    harrison  highland park  hopatcong  new brunswick     newark  \
# YEAR
# 1990   43.300833            NaN        NaN            NaN        NaN
# 1991   50.837967            NaN        NaN            NaN        NaN
# 1992   22.649087            NaN        NaN            NaN        NaN
# 1993   47.096318            NaN        NaN            NaN        NaN
# 1994   25.249398            NaN        NaN            NaN        NaN
# 1995   43.150090            NaN        NaN            NaN        NaN
# 1996   46.994029            NaN        NaN     121.563199        NaN
# 1997  125.681704            NaN        NaN     130.930780        NaN
# 1998         NaN            NaN        NaN     149.719777        NaN
# 1999   80.798073            NaN        NaN      89.745728        NaN
# 2000         NaN            NaN        NaN      74.725297        NaN
# 2001         NaN      72.997140  64.329436     111.711089        NaN
# 2002         NaN     123.797421  12.436271      51.467856        NaN
# 2003         NaN      11.946357  39.946809      53.244466        NaN
# 2004         NaN      23.741971  24.156514     252.870836        NaN
# 2005         NaN      32.447361   2.261140     812.395340        NaN
# 2006         NaN       3.806253   3.165596      88.130628        NaN
# 2007         NaN       3.919310  31.354476       9.690600        NaN
# 2008         NaN       4.974508  43.715375      13.136147        NaN
# 2009         NaN      57.282216   1.846598       7.429460        NaN
# 2010         NaN       5.728222   3.806253       5.975870        NaN
# 2011         NaN      56.151646  47.860799       5.383667        NaN
# 2012         NaN       8.856132  20.576375       5.383667        NaN
# 2013         NaN       5.690536  11.833300       4.629954        NaN
# 2014         NaN       3.237199   1.959655       6.029707        NaN
# 2015         NaN       2.212149   1.277544       4.199260        NaN
# 2016         NaN            NaN   1.164487       4.522280  26.863066
#
# City  north plainfield   paterson
# YEAR
# 1990         50.272682        NaN
# 1991         19.144320        NaN
# 1992         67.758832        NaN
# 1993         57.206845        NaN
# 1994         63.581106        NaN
# 1995         40.635918        NaN
# 1996         65.034697        NaN
# 1997               NaN        NaN
# 1998               NaN        NaN
# 1999               NaN        NaN
# 2000               NaN        NaN
# 2001               NaN        NaN
# 2002               NaN        NaN
# 2003               NaN        NaN
# 2004               NaN        NaN
# 2005               NaN   4.478673
# 2006               NaN   4.624032
# 2007               NaN        NaN
# 2008               NaN        NaN
# 2009               NaN        NaN
# 2010               NaN  85.546468
# 2011               NaN   4.861451
# 2012               NaN        NaN
# 2013               NaN        NaN
# 2014               NaN        NaN
# 2015               NaN        NaN
# 2016               NaN        NaN

# %%
# flattening groupby into a level df

clean_means = mean_by_year_df.reset_index().pivot('YEAR','City','SAMPLE_VALUE_STD_FINAL_UG_M3')
clean_means
# Out:
# City   bayonne     camden     darby  elizabeth     ewing  fort lee   harrison  \
# YEAR
# 1990       NaN   8.306651       NaN        NaN       NaN       NaN  17.255849
# 1991       NaN  20.145682       NaN        NaN       NaN       NaN  25.856137
# 1992       NaN   9.176460       NaN        NaN       NaN       NaN  13.968821
# 1993       NaN   7.367548       NaN        NaN       NaN       NaN  14.758426
# 1994       NaN   9.172692       NaN        NaN       NaN       NaN  16.714132
# 1995       NaN   5.763008       NaN        NaN  2.132794       NaN  11.819542
# 1996       NaN   5.394848       NaN        NaN  2.633098       NaN  15.772350
# 1997       NaN   3.793817       NaN        NaN  1.980542       NaN  25.030821
# 1998       NaN   3.359554       NaN        NaN  1.678832       NaN        NaN
# 1999       NaN   3.006842       NaN        NaN  1.543369       NaN  14.893645
# 2000       NaN   3.003370       NaN   6.405114  1.515121       NaN        NaN
# 2001       NaN   2.992905       NaN   5.670123  1.315370       NaN        NaN
# 2002       NaN   2.200479       NaN   5.182807  1.283220       NaN        NaN
# 2003       NaN   2.597708       NaN   5.064456  1.323148       NaN        NaN
# 2004       NaN   3.369962       NaN   3.776104  1.099960       NaN        NaN
# 2005       NaN   2.236596       NaN   3.909888  1.062639       NaN        NaN
# 2006       NaN   2.049005       NaN   3.116865  1.036375       NaN        NaN
# 2007       NaN   1.934413       NaN   2.638182  0.861792       NaN        NaN
# 2008       NaN   1.689204       NaN   5.054765  0.991922       NaN        NaN
# 2009       NaN        NaN  2.586852   3.153109  0.881439       NaN        NaN
# 2010       NaN        NaN  2.072712   3.269232  0.727903       NaN        NaN
# 2011       NaN        NaN       NaN   2.847616       NaN       NaN        NaN
# 2012       NaN        NaN       NaN   2.087354       NaN       NaN        NaN
# 2013       NaN   4.126779       NaN   2.477987       NaN       NaN        NaN
# 2014       NaN   2.508630       NaN   1.662002       NaN       NaN        NaN
# 2015       NaN   6.145173       NaN   1.844776       NaN       NaN        NaN
# 2016  2.686103   2.768117       NaN   2.886584       NaN  1.720701        NaN
#
# City  highland park  hopatcong  new brunswick    newark  north plainfield  \
# YEAR
# 1990            NaN        NaN            NaN       NaN         13.286292
# 1991            NaN        NaN            NaN       NaN          2.127147
# 1992            NaN        NaN            NaN       NaN         32.028631
# 1993            NaN        NaN            NaN       NaN         14.570420
# 1994            NaN        NaN            NaN       NaN         26.799894
# 1995            NaN        NaN            NaN       NaN         16.837717
# 1996            NaN        NaN       5.207059       NaN         25.323274
# 1997            NaN        NaN       5.032487       NaN               NaN
# 1998            NaN        NaN       4.810409       NaN               NaN
# 1999            NaN        NaN       3.577303       NaN               NaN
# 2000            NaN        NaN       3.338680       NaN               NaN
# 2001      18.177054   9.169394       4.017518       NaN               NaN
# 2002       7.448717   2.768788       2.741088       NaN               NaN
# 2003       3.493240   2.083290       2.714555       NaN               NaN
# 2004       3.028672   1.762631      12.927972       NaN               NaN
# 2005       2.901796   0.977566       3.586696       NaN               NaN
# 2006       1.266017   0.683280       1.424445       NaN               NaN
# 2007       1.105069   2.424348       1.377136       NaN               NaN
# 2008       1.175382   1.865888       1.787075       NaN               NaN
# 2009       1.917926   0.446730       2.234760       NaN               NaN
# 2010       1.194430   0.579566       0.948864       NaN               NaN
# 2011       2.055298   1.420750       0.787686       NaN               NaN
# 2012       3.579573   5.240717       0.764620       NaN               NaN
# 2013       1.782161   1.533807       0.640002       NaN               NaN
# 2014       0.805594   0.615265       0.531517       NaN               NaN
# 2015       0.813947   0.474634       0.666408       NaN               NaN
# 2016            NaN   0.396674       0.648663  1.670011               NaN
#
# City   paterson
# YEAR
# 1990        NaN
# 1991        NaN
# 1992        NaN
# 1993        NaN
# 1994        NaN
# 1995        NaN
# 1996        NaN
# 1997        NaN
# 1998        NaN
# 1999        NaN
# 2000        NaN
# 2001        NaN
# 2002        NaN
# 2003        NaN
# 2004        NaN
# 2005   3.052078
# 2006   0.970602
# 2007        NaN
# 2008        NaN
# 2009        NaN
# 2010  10.790390
# 2011   2.688728
# 2012        NaN
# 2013        NaN
# 2014        NaN
# 2015        NaN
# 2016        NaN

# %%
# a graphic look into city mean by year
# the drop off in the original data looks like it is due to the end of...
# ...data sampling sites for north plainfeild and harrison which recorded incredibly high levels!!

colors = ['red', 'blue', 'tan', 'orange', 'green', 'purple', 'brown', 'yellow', 'pink', 'grey', 'aqua', 'lightblue', 'maroon']

clean_means.plot(sharex='all', grid=True, figsize=(18,7), color=colors)
plt.legend(bbox_to_anchor=(1.05,1))
plt.ylabel('µg/m3 (micrograms per cubic meter)')
plt.ti
# Out:
# Text(0, 0.5, 'µg/m3 (micrograms per cubic meter)')

# %%
colors = ['red', 'blue', 'tan', 'orange', 'green', 'purple', 'brown', 'yellow', 'pink', 'grey', 'aqua', 'lightblue', 'maroon']

clean_max.plot(sharex='all', grid=True, figsize=(18,7), color=colors, label=True)
plt.legend(bbox_to_anchor=(1.05,1))

# %%
clean_means['camden'].plot(kind='bar')
plt.title('Camden')
# Out:
# Text(0.5, 1.0, 'Camden')

# %%
clean_means['ewing'].plot(kind='bar')

# %%
plt.subplots(2, 2, sharex='col', figsize=(20,10))
clean_means['ewing'].plot(kind='bar')
